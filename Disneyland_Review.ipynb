# %%
# mount your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import modules
import numpy as np
import pandas as pd

# plotting
import seaborn as sns
import matplotlib.pyplot as plt

# need to add nltk imports up here
# link: https://www.nltk.org/
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
dataframe = pd.read_csv("/content/drive/MyDrive/DS Project/DisneylandReviews.csv", encoding="latin-1")
dataframe.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong

# %%
print(dataframe["Review_Text"][0])
print(dataframe["Review_Text"][1])
print(dataframe["Review_Text"][2])
# Out:
# If you've ever been to Disneyland anywhere you'll find Disneyland Hong Kong very similar in the layout when you walk into main street! It has a very familiar feel. One of the rides  its a Small World  is absolutely fabulous and worth doing. The day we visited was fairly hot and relatively busy but the queues moved fairly well.
# Its been a while since d last time we visit HK Disneyland .. Yet, this time we only stay in Tomorrowland .. AKA Marvel land!Now they have Iron Man Experience n d Newly open Ant Man n d Wasp!!Ironman .. Great feature n so Exciting, especially d whole scenery of HK (HK central area to Kowloon)!Antman .. Changed by previous Buzz lightyear! More or less d same, but I'm expecting to have something most!!However, my boys like it!!Space Mountain .. Turns into Star Wars!! This 1 is Great!!!For cast members (staffs) .. Felt bit MINUS point from before!!! Just dun feel like its a Disney brand!! Seems more local like Ocean Park or even worst!!They got no SMILING face, but just wanna u to enter n attraction n leave!!Hello this is supposed to be Happiest Place on Earth brand!! But, just really Dont feel it!!Bakery in Main Street now have more attractive delicacies n Disney theme sweets .. These are Good Points!!Last, they also have Starbucks now inside the theme park!!
# Thanks God it wasn   t too hot or too humid when I was visiting the park   otherwise it would be a big issue (there is not a lot of shade).I have arrived around 10:30am and left at 6pm. Unfortunately I didn   t last until evening parade, but 8.5 hours was too much for me.There is plenty to do and everyone will find something interesting for themselves to enjoy.It wasn   t extremely busy and the longest time I had to queue for certain attractions was 45 minutes (which is really not that bad).Although I had an amazing time, I felt a bit underwhelmed with choice of rides and attractions. The park itself is quite small (I was really expecting something grand   even the main castle which was closed by the way was quite small).The food options are good, few coffee shops (including Starbucks) and plenty of gift shops. There was no issue with toilets as they are everywhere.All together it was a great day out and I really enjoyed it.

# %%
dataframe['Branch'].value_counts()
# Out:
# Branch
# Disneyland_California    19406
# Disneyland_Paris         13630
# Disneyland_HongKong       9620
# Name: count, dtype: int64

# %%
df_California= dataframe[dataframe['Branch']=="Disneyland_California"]
df_California.head()
# Out:
#       Review_ID  Rating Year_Month Reviewer_Location  \
# 9620  670801367       5     2019-4     United States
# 9621  670760708       5     2019-4     United States
# 9622  670565072       4     2019-5         Australia
# 9623  670544335       5     2019-4     United States
# 9624  670472278       5     2019-4            Canada
#
#                                             Review_Text                 Branch
# 9620  This place has always been and forever will be...  Disneyland_California
# 9621  A great day of simple fun and thrills. Bring c...  Disneyland_California
# 9622  All and all a great day was had. The crowds ar...  Disneyland_California
# 9623  Having been to the Florida location numerous t...  Disneyland_California
# 9624  Had the 4 day pass, spent 3 at DL and one at C...  Disneyland_California

# %%
df_Paris= dataframe[dataframe['Branch']=="Disneyland_Paris"]
df_Paris.head()
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 29026  670721950       5     2019-3  United Arab Emirates
# 29027  670686565       4     2018-6        United Kingdom
# 29028  670606796       5     2019-4        United Kingdom
# 29029  670586937       4     2019-4             Australia
# 29030  670535589       5    missing                France
#
#                                              Review_Text            Branch
# 29026  We've been to Disneyland Hongkong and Tokyo, s...  Disneyland_Paris
# 29027  I went to Disneyland Paris in April 2018 on Ea...  Disneyland_Paris
# 29028  What a fantastic place, the queues were decent...  Disneyland_Paris
# 29029  We didn't realise it was school holidays when ...  Disneyland_Paris
# 29030  A Trip to Disney makes you all warm and fuzzy ...  Disneyland_Paris

# %%
df_HongKong= dataframe[dataframe['Branch']=="Disneyland_HongKong"]
df_HongKong.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong

# %%
df_California.head()
# Out:
#       Review_ID  Rating Year_Month Reviewer_Location  \
# 9620  670801367       5     2019-4     United States
# 9621  670760708       5     2019-4     United States
# 9622  670565072       4     2019-5         Australia
# 9623  670544335       5     2019-4     United States
# 9624  670472278       5     2019-4            Canada
#
#                                             Review_Text                 Branch
# 9620  This place has always been and forever will be...  Disneyland_California
# 9621  A great day of simple fun and thrills. Bring c...  Disneyland_California
# 9622  All and all a great day was had. The crowds ar...  Disneyland_California
# 9623  Having been to the Florida location numerous t...  Disneyland_California
# 9624  Had the 4 day pass, spent 3 at DL and one at C...  Disneyland_California

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42656 entries, 0 to 42655
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          42656 non-null  int64
#  1   Rating             42656 non-null  int64
#  2   Year_Month         42656 non-null  object
#  3   Reviewer_Location  42656 non-null  object
#  4   Review_Text        42656 non-null  object
#  5   Branch             42656 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 2.0+ MB

# %%
# Call the isnull() method on the dataframe object
missing_values = dataframe.isnull().sum()

# Print the number of missing values in each column
print(missing_values)
# Out:
# Review_ID            0
# Rating               0
# Year_Month           0
# Reviewer_Location    0
# Review_Text          0
# Branch               0
# dtype: int64

# %%
df_HongKong["Rating"].value_counts()
# Out:
# Rating
# 5    4517
# 4    3230
# 3    1365
# 2     336
# 1     172
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(x="Rating", data=df_California,
                   order = df_California['Rating'].value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
plt.show()
# Out:
# <ipython-input-14-5bd658f5731a>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(x="Rating", data=df_Paris,
                   order = df_Paris['Rating'].value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
plt.show()
# Out:
# <ipython-input-15-84e756ba14b9>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(x="Rating", data=df_HongKong,
                   order = df_HongKong['Rating'].value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
plt.show()
# Out:
# <ipython-input-16-f23d8d1bf1ab>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

# %% [markdown]
# # California Disneyland Analysis

# %%
# one line of code! we made a new column and populated it
df_California['New_Rating'] = np.where(df_California['Rating'] < 3, 0, 1)

df_California.head()
# Out:
# <ipython-input-17-119f3bf7647a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_California['New_Rating'] = np.where(df_California['Rating'] < 3, 0, 1)
#       Review_ID  Rating Year_Month Reviewer_Location  \
# 9620  670801367       5     2019-4     United States
# 9621  670760708       5     2019-4     United States
# 9622  670565072       4     2019-5         Australia
# 9623  670544335       5     2019-4     United States
# 9624  670472278       5     2019-4            Canada
#
#                                             Review_Text  \
# 9620  This place has always been and forever will be...
# 9621  A great day of simple fun and thrills. Bring c...
# 9622  All and all a great day was had. The crowds ar...
# 9623  Having been to the Florida location numerous t...
# 9624  Had the 4 day pass, spent 3 at DL and one at C...
#
#                      Branch  New_Rating
# 9620  Disneyland_California           1
# 9621  Disneyland_California           1
# 9622  Disneyland_California           1
# 9623  Disneyland_California           1
# 9624  Disneyland_California           1

# %% [markdown]
# ## Exploring the text data

# %% [markdown]
# ###High Rating Reviews Analysis for California DisneyLand

# %%
df_California_high = df_California[df_California['New_Rating']==1]
df_California_high.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18160 entries, 9620 to 29025
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          18160 non-null  int64
#  1   Rating             18160 non-null  int64
#  2   Year_Month         18160 non-null  object
#  3   Reviewer_Location  18160 non-null  object
#  4   Review_Text        18160 non-null  object
#  5   Branch             18160 non-null  object
#  6   New_Rating         18160 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
df_California_high.head()
# Out:
#       Review_ID  Rating Year_Month Reviewer_Location  \
# 9620  670801367       5     2019-4     United States
# 9621  670760708       5     2019-4     United States
# 9622  670565072       4     2019-5         Australia
# 9623  670544335       5     2019-4     United States
# 9624  670472278       5     2019-4            Canada
#
#                                             Review_Text  \
# 9620  This place has always been and forever will be...
# 9621  A great day of simple fun and thrills. Bring c...
# 9622  All and all a great day was had. The crowds ar...
# 9623  Having been to the Florida location numerous t...
# 9624  Had the 4 day pass, spent 3 at DL and one at C...
#
#                      Branch  New_Rating
# 9620  Disneyland_California           1
# 9621  Disneyland_California           1
# 9622  Disneyland_California           1
# 9623  Disneyland_California           1
# 9624  Disneyland_California           1

# %%
print(df_California_high.index)
# Out:
# Index([ 9620,  9621,  9622,  9623,  9624,  9625,  9626,  9627,  9628,  9629,
#        ...
#        29015, 29016, 29017, 29018, 29019, 29020, 29021, 29022, 29024, 29025],
#       dtype='int64', length=18160)

# %%
df_California_high = df_California_high.reset_index(drop=True)

# %%
print(df_California_high['Review_Text'][0])
print(df_California_high['Review_Text'][1])
print(df_California_high['Review_Text'][2])
# Out:
# This place has always been and forever will be special. The feeling you get entering the park, seeing the characters and different attractions is just priceless. This is definitely a dream trip for all ages, especially young kids. Spend the money and go to Disneyland, you will NOT regret it
# A great day of simple fun and thrills. Bring cash, nothing is cheap, but we knew that it's Disney. But they are great letting you bring in your own food, drinks, etc but read the list closely, we list several items at the entry gates (selfy sticks, glass refill bottles, etc). It is worth buying the photo pass and fastpass. Have fun!
# All and all a great day was had. The crowds are huge and ride times sometimes up to a 50 min wait but worth it. Very disappointed the castle was under repair and covered but we understood. If you want to take a short cut on the rides grab a Max Pass for 15 each it allows you to book a time every 90mins and believe me it's a great feeling floating past the ques.

# %% [markdown]
# ###Lowercase

# %%
df_California_high['Review_Text'] = df_California_high['Review_Text'].str.lower()
df_California_high.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  670801367       5     2019-4     United States
# 1  670760708       5     2019-4     United States
# 2  670565072       4     2019-5         Australia
# 3  670544335       5     2019-4     United States
# 4  670472278       5     2019-4            Canada
#
#                                          Review_Text                 Branch  \
# 0  this place has always been and forever will be...  Disneyland_California
# 1  a great day of simple fun and thrills. bring c...  Disneyland_California
# 2  all and all a great day was had. the crowds ar...  Disneyland_California
# 3  having been to the florida location numerous t...  Disneyland_California
# 4  had the 4 day pass, spent 3 at dl and one at c...  Disneyland_California
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
print(df_California_high['Review_Text'][0])
print(df_California_high['Review_Text'][1])
print(df_California_high['Review_Text'][2])
# Out:
# this place has always been and forever will be special. the feeling you get entering the park, seeing the characters and different attractions is just priceless. this is definitely a dream trip for all ages, especially young kids. spend the money and go to disneyland, you will not regret it
# a great day of simple fun and thrills. bring cash, nothing is cheap, but we knew that it's disney. but they are great letting you bring in your own food, drinks, etc but read the list closely, we list several items at the entry gates (selfy sticks, glass refill bottles, etc). it is worth buying the photo pass and fastpass. have fun!
# all and all a great day was had. the crowds are huge and ride times sometimes up to a 50 min wait but worth it. very disappointed the castle was under repair and covered but we understood. if you want to take a short cut on the rides grab a max pass for 15 each it allows you to book a time every 90mins and believe me it's a great feeling floating past the ques.

# %% [markdown]
# ###Strip funky characters (!,~-@$% etc)

# %%
df_California_high['Review_Text'] = df_California_high['Review_Text'].str.replace('[^A-z ]','').str.replace(' +',' ').str.strip()
df_California_high.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  670801367       5     2019-4     United States
# 1  670760708       5     2019-4     United States
# 2  670565072       4     2019-5         Australia
# 3  670544335       5     2019-4     United States
# 4  670472278       5     2019-4            Canada
#
#                                          Review_Text                 Branch  \
# 0  this place has always been and forever will be...  Disneyland_California
# 1  a great day of simple fun and thrills. bring c...  Disneyland_California
# 2  all and all a great day was had. the crowds ar...  Disneyland_California
# 3  having been to the florida location numerous t...  Disneyland_California
# 4  had the 4 day pass, spent 3 at dl and one at c...  Disneyland_California
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
print(df_California_high['Review_Text'][0])
print(df_California_high['Review_Text'][1])
print(df_California_high['Review_Text'][2])
# Out:
# this place has always been and forever will be special. the feeling you get entering the park, seeing the characters and different attractions is just priceless. this is definitely a dream trip for all ages, especially young kids. spend the money and go to disneyland, you will not regret it
# a great day of simple fun and thrills. bring cash, nothing is cheap, but we knew that it's disney. but they are great letting you bring in your own food, drinks, etc but read the list closely, we list several items at the entry gates (selfy sticks, glass refill bottles, etc). it is worth buying the photo pass and fastpass. have fun!
# all and all a great day was had. the crowds are huge and ride times sometimes up to a 50 min wait but worth it. very disappointed the castle was under repair and covered but we understood. if you want to take a short cut on the rides grab a max pass for 15 each it allows you to book a time every 90mins and believe me it's a great feeling floating past the ques.

# %% [markdown]
# ###Stop words

# %%
import nltk
from nltk.corpus import stopwords


nltk.download('stopwords') # this makes sure these are downloaded if you haven't already!
print(stopwords.words('english'))

stop = stopwords.words('english') # see why it's important to turn everything lower case? all of your stopwords are!
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df_California_high['Review_Text'] = df_California_high['Review_Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
df_California_high.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  670801367       5     2019-4     United States
# 1  670760708       5     2019-4     United States
# 2  670565072       4     2019-5         Australia
# 3  670544335       5     2019-4     United States
# 4  670472278       5     2019-4            Canada
#
#                                          Review_Text                 Branch  \
# 0  place always forever special. feeling get ente...  Disneyland_California
# 1  great day simple fun thrills. bring cash, noth...  Disneyland_California
# 2  great day had. crowds huge ride times sometime...  Disneyland_California
# 3  florida location numerous times years know one...  Disneyland_California
# 4  4 day pass, spent 3 dl one ca. great place vis...  Disneyland_California
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
print(df_California_high['Review_Text'][0])
print(df_California_high['Review_Text'][1])
print(df_California_high['Review_Text'][2])
# Out:
# place always forever special. feeling get entering park, seeing characters different attractions priceless. definitely dream trip ages, especially young kids. spend money go disneyland, regret
# great day simple fun thrills. bring cash, nothing cheap, knew disney. great letting bring food, drinks, etc read list closely, list several items entry gates (selfy sticks, glass refill bottles, etc). worth buying photo pass fastpass. fun!
# great day had. crowds huge ride times sometimes 50 min wait worth it. disappointed castle repair covered understood. want take short cut rides grab max pass 15 allows book time every 90mins believe great feeling floating past ques.

# %% [markdown]
# ###Text EDA on the California high rating Data

# %% [markdown]
# ### Most common words

# %%
myTable = df_California_high['Review_Text'].str.split(expand=True).stack().value_counts()
myTable[0:20] # too cool!
# Out:
# park          12481
# disneyland    11401
# disney        10136
# get            9619
# rides          9549
# time           9048
# day            7861
# go             7641
# one            6355
# great          6147
# ride           5751
# fast           4879
# would          4798
# place          4769
# like           4417
# pass           4341
# much           4240
# really         4187
# see            4118
# wait           3942
# Name: count, dtype: int64

# %%
x = df_California_high['Review_Text'].str.split(expand=True).stack().value_counts()
x = pd.DataFrame(x)
# reset the index
x.reset_index(inplace=True)
# rename the columns
x.rename(columns={x.columns[0]:'word', x.columns[1]:'frequency'}, inplace=True)
x.head()
# Out:
#          word  frequency
# 0        park      12481
# 1  disneyland      11401
# 2      disney      10136
# 3         get       9619
# 4       rides       9549

# %%
x = x[0:20] # wanna play? change the 20 to 10 or 30 and see what happens...
            # you need to run the previous cell first
x.plot(x='word', y='frequency')
plt.xticks(np.arange(len(x)), x['word'], rotation=90)
plt.suptitle('Top Words in DisneyLand California high rated Review')
plt.show()

# %% [markdown]
# ### Word Cloud

# %%
from wordcloud import WordCloud

# Generate a word cloud image
wordcloud = WordCloud().generate(' '.join(df_California_high['Review_Text']))

# # Display the generated image:
# # the matplotlib way:
# import matplotlib.pyplot as plt
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(' '.join(df_California_high['Review_Text']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ###Tokenizer

# %%
df_California_high['Review_Text'] = df_California_high.apply(lambda row: nltk.word_tokenize(row['Review_Text']), axis=1)
df_California_high.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  670801367       5     2019-4     United States
# 1  670760708       5     2019-4     United States
# 2  670565072       4     2019-5         Australia
# 3  670544335       5     2019-4     United States
# 4  670472278       5     2019-4            Canada
#
#                                          Review_Text                 Branch  \
# 0  [place, always, forever, special, ., feeling, ...  Disneyland_California
# 1  [great, day, simple, fun, thrills, ., bring, c...  Disneyland_California
# 2  [great, day, had, ., crowds, huge, ride, times...  Disneyland_California
# 3  [florida, location, numerous, times, years, kn...  Disneyland_California
# 4  [4, day, pass, ,, spent, 3, dl, one, ca, ., gr...  Disneyland_California
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
print(df_California_high['Review_Text'][0])
print(df_California_high['Review_Text'][1])
print(df_California_high['Review_Text'][2])
# Out:
# ['place', 'always', 'forever', 'special', '.', 'feeling', 'get', 'entering', 'park', ',', 'seeing', 'characters', 'different', 'attractions', 'priceless', '.', 'definitely', 'dream', 'trip', 'ages', ',', 'especially', 'young', 'kids', '.', 'spend', 'money', 'go', 'disneyland', ',', 'regret']
# ['great', 'day', 'simple', 'fun', 'thrills', '.', 'bring', 'cash', ',', 'nothing', 'cheap', ',', 'knew', 'disney', '.', 'great', 'letting', 'bring', 'food', ',', 'drinks', ',', 'etc', 'read', 'list', 'closely', ',', 'list', 'several', 'items', 'entry', 'gates', '(', 'selfy', 'sticks', ',', 'glass', 'refill', 'bottles', ',', 'etc', ')', '.', 'worth', 'buying', 'photo', 'pass', 'fastpass', '.', 'fun', '!']
# ['great', 'day', 'had', '.', 'crowds', 'huge', 'ride', 'times', 'sometimes', '50', 'min', 'wait', 'worth', 'it', '.', 'disappointed', 'castle', 'repair', 'covered', 'understood', '.', 'want', 'take', 'short', 'cut', 'rides', 'grab', 'max', 'pass', '15', 'allows', 'book', 'time', 'every', '90mins', 'believe', 'great', 'feeling', 'floating', 'past', 'ques', '.']

# %% [markdown]
# ## Lexicon Normalization

# %% [markdown]
# ###Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# this is the function we will use
ps = PorterStemmer()

filtered_sent = df_California_high['Review_Text'][1]

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['great', 'day', 'simple', 'fun', 'thrills', '.', 'bring', 'cash', ',', 'nothing', 'cheap', ',', 'knew', 'disney', '.', 'great', 'letting', 'bring', 'food', ',', 'drinks', ',', 'etc', 'read', 'list', 'closely', ',', 'list', 'several', 'items', 'entry', 'gates', '(', 'selfy', 'sticks', ',', 'glass', 'refill', 'bottles', ',', 'etc', ')', '.', 'worth', 'buying', 'photo', 'pass', 'fastpass', '.', 'fun', '!']
# Stemmed Sentence: ['great', 'day', 'simpl', 'fun', 'thrill', '.', 'bring', 'cash', ',', 'noth', 'cheap', ',', 'knew', 'disney', '.', 'great', 'let', 'bring', 'food', ',', 'drink', ',', 'etc', 'read', 'list', 'close', ',', 'list', 'sever', 'item', 'entri', 'gate', '(', 'selfi', 'stick', ',', 'glass', 'refil', 'bottl', ',', 'etc', ')', '.', 'worth', 'buy', 'photo', 'pass', 'fastpass', '.', 'fun', '!']

# %%
df_California_high['Stemmed'] = df_California_high['Review_Text'].apply(lambda x: [ps.stem(y) for y in x]) # Stem every word.

# %%
# check your work!
print(df_California_high['Review_Text'][0]) # reported
print(df_California_high['Stemmed'][0]) # report

print(df_California_high['Review_Text'][10]) # note the difference between inches, reported, covered
print(df_California_high['Stemmed'][10]) # inch, report, cover
# Out:
# ['place', 'always', 'forever', 'special', '.', 'feeling', 'get', 'entering', 'park', ',', 'seeing', 'characters', 'different', 'attractions', 'priceless', '.', 'definitely', 'dream', 'trip', 'ages', ',', 'especially', 'young', 'kids', '.', 'spend', 'money', 'go', 'disneyland', ',', 'regret']
# ['place', 'alway', 'forev', 'special', '.', 'feel', 'get', 'enter', 'park', ',', 'see', 'charact', 'differ', 'attract', 'priceless', '.', 'definit', 'dream', 'trip', 'age', ',', 'especi', 'young', 'kid', '.', 'spend', 'money', 'go', 'disneyland', ',', 'regret']
# ['going', 'disneyland', 'since', 'early', '60', 's', ',', 'magic', 'never', 'gets', 'old', '.', '4th', 'visit', 'year', '.', 'developed', 'strategy', 'works', 'best', 'us', '.', 'stay', 'disney', 'resort', 'get', '0700.', 'actually', 'get', '5', 'rides', 'less', '2', 'hours', '.', 'day', 'goes', 'crowds', 'thicken', 'wait', 'times', 'hour', 'making', 'difficult', 'experience', 'everything', '.', 'max', 'pass', 'worth', 'extra', '$', '.', 'nightfall', 'crowds', 'overwhelming', ',', 'early', 'better', '.']
# ['go', 'disneyland', 'sinc', 'earli', '60', 's', ',', 'magic', 'never', 'get', 'old', '.', '4th', 'visit', 'year', '.', 'develop', 'strategi', 'work', 'best', 'us', '.', 'stay', 'disney', 'resort', 'get', '0700.', 'actual', 'get', '5', 'ride', 'less', '2', 'hour', '.', 'day', 'goe', 'crowd', 'thicken', 'wait', 'time', 'hour', 'make', 'difficult', 'experi', 'everyth', '.', 'max', 'pass', 'worth', 'extra', '$', '.', 'nightfal', 'crowd', 'overwhelm', ',', 'earli', 'better', '.']

# %% [markdown]
# ###Low Rating Reviews Analysis for California DisneyLand

# %%
df_California_low = df_California[df_California['New_Rating']==0]
df_California_low.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1246 entries, 9633 to 29023
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          1246 non-null   int64
#  1   Rating             1246 non-null   int64
#  2   Year_Month         1246 non-null   object
#  3   Reviewer_Location  1246 non-null   object
#  4   Review_Text        1246 non-null   object
#  5   Branch             1246 non-null   object
#  6   New_Rating         1246 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 77.9+ KB

# %%
df_California_low.head()
# Out:
#       Review_ID  Rating Year_Month Reviewer_Location  \
# 9633  669660324       2    2018-10     United States
# 9636  669505006       1    missing     United States
# 9642  668730191       2     2019-4    United Kingdom
# 9650  667955757       1     2019-1         Australia
# 9687  664615049       1     2019-4         Australia
#
#                                             Review_Text  \
# 9633  It is no doubt a legendary place but I just do...
# 9636  I   ve been to Disneyland several times in the...
# 9642  My partner and I paid $149 each for tickets to...
# 9650  To all who comes to this happy place, welcome....
# 9687  I am really disappointed with Disneyland.Old, ...
#
#                      Branch  New_Rating
# 9633  Disneyland_California           0
# 9636  Disneyland_California           0
# 9642  Disneyland_California           0
# 9650  Disneyland_California           0
# 9687  Disneyland_California           0

# %%
print(df_California_low.index)
# Out:
# Index([ 9633,  9636,  9642,  9650,  9687,  9694,  9701,  9702,  9715,  9716,
#        ...
#        28933, 28934, 28939, 28960, 28962, 28983, 28987, 28991, 29010, 29023],
#       dtype='int64', length=1246)

# %%
df_California_low = df_California_low.reset_index(drop=True)

# %%
print(df_California_low['Review_Text'][0])
print(df_California_low['Review_Text'][1])
print(df_California_low['Review_Text'][2])
# Out:
# It is no doubt a legendary place but I just dont think it's worth the money and headache of overcrowding and overpriced everything. Disney continues to raise the price of admission and the crowds are ridiculous every single day. There are plenty of things to do in SoCal that are cheap or free. Save your family hundreds of dollars and go somewhere else.
# my partner and i paid $149 each for tickets to this park as my partner wanted to see the original disney castle.when paying for the tickets nothing was mentioned about a couple of issues we had.firstly we walked through and tried to take a photo using a selfie stick to be told we either have to throw it away or take it back to the car or hotel as they are banned. so we had to leave and come back again.then once we finally got back in we saw countless people with cameras on selfie sticks which was very annoying, but not as annoying as them not pre telling us before paying that the castle isn   t even visible as they are working on it or something. it was just wooden panels with a castle painted on it so we paid full price for partial access and activities to be available to us.we should have been told as we   d have left the park for another la holiday and not wasted $300.disney this is unacceptable and a true disappointment the only good thing was out breakfast in the carnation cafe where the staff were superb and the apple cinnamon pancakes to die for.all in all a very expensive disappointing day thanks to disney not pre advising people at the gate as to what works were or are being carried out.

# %% [markdown]
# ##Strip funky characters (!,~-@$% etc)

# %%
df_California_low['Review_Text'] = df_California_low['Review_Text'].str.replace('[^A-z ]','').str.replace(' +',' ').str.strip()
df_California_low.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  669660324       2    2018-10     United States
# 1  669505006       1    missing     United States
# 2  668730191       2     2019-4    United Kingdom
# 3  667955757       1     2019-1         Australia
# 4  664615049       1     2019-4         Australia
#
#                                          Review_Text                 Branch  \
# 0  it is no doubt a legendary place but i just do...  Disneyland_California
# 1  i   ve been to disneyland several times in the...  Disneyland_California
# 2  my partner and i paid $149 each for tickets to...  Disneyland_California
# 3  to all who comes to this happy place, welcome....  Disneyland_California
# 4  i am really disappointed with disneyland.old, ...  Disneyland_California
#
#    New_Rating
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
print(df_California_low['Review_Text'][0])
print(df_California_low['Review_Text'][1])
print(df_California_low['Review_Text'][2])
# Out:
# it is no doubt a legendary place but i just dont think it's worth the money and headache of overcrowding and overpriced everything. disney continues to raise the price of admission and the crowds are ridiculous every single day. there are plenty of things to do in socal that are cheap or free. save your family hundreds of dollars and go somewhere else.
# i   ve been to disneyland several times in the past 3 decades. this visit, i sensed the employees were disgruntled or unhappy. very few smiles from the staff. in addition, the staff was prowling for people crossing the ropes while fantasmic was on. why do we need a fastpass to enter to watch the fan tasmic show when everyone has been situated and there is tons of space for paying customers without a fastpass? see attached picture. through the whole show, the entire space was unoccupied while there were 5 8 yr olds next to us straining to catch a glimpse.if you wanna pay $129 to stand in line for hours to ride an average of 9 rides that last 3 to 11 minute, this is the place for you. disneyland has become so greedy that they overcrowd by double capacity just to make money without a care for their customers. it   s ridiculous to have minimal places to sit and rest with this large of a park. i highly recommend universal studios vip pass over this mess.
# my partner and i paid $149 each for tickets to this park as my partner wanted to see the original disney castle.when paying for the tickets nothing was mentioned about a couple of issues we had.firstly we walked through and tried to take a photo using a selfie stick to be told we either have to throw it away or take it back to the car or hotel as they are banned. so we had to leave and come back again.then once we finally got back in we saw countless people with cameras on selfie sticks which was very annoying, but not as annoying as them not pre telling us before paying that the castle isn   t even visible as they are working on it or something. it was just wooden panels with a castle painted on it so we paid full price for partial access and activities to be available to us.we should have been told as we   d have left the park for another la holiday and not wasted $300.disney this is unacceptable and a true disappointment the only good thing was out breakfast in the carnation cafe where the staff were superb and the apple cinnamon pancakes to die for.all in all a very expensive disappointing day thanks to disney not pre advising people at the gate as to what works were or are being carried out.

# %% [markdown]
# ##Stop words

# %%
import nltk
from nltk.corpus import stopwords


nltk.download('stopwords') # this makes sure these are downloaded if you haven't already!
print(stopwords.words('english'))

stop = stopwords.words('english') # see why it's important to turn everything lower case? all of your stopwords are!
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_California_low['Review_Text'] = df_California_low['Review_Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
df_California_low.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  669660324       2    2018-10     United States
# 1  669505006       1    missing     United States
# 2  668730191       2     2019-4    United Kingdom
# 3  667955757       1     2019-1         Australia
# 4  664615049       1     2019-4         Australia
#
#                                          Review_Text                 Branch  \
# 0  doubt legendary place dont think worth money h...  Disneyland_California
# 1  disneyland several times past 3 decades. visit...  Disneyland_California
# 2  partner paid $149 tickets park partner wanted ...  Disneyland_California
# 3  comes happy place, welcome. well walts vision ...  Disneyland_California
# 4  really disappointed disneyland.old, tired, cro...  Disneyland_California
#
#    New_Rating
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
print(df_California_low['Review_Text'][0])
print(df_California_low['Review_Text'][1])
print(df_California_low['Review_Text'][2])
# Out:
# doubt legendary place dont think worth money headache overcrowding overpriced everything. disney continues raise price admission crowds ridiculous every single day. plenty things socal cheap free. save family hundreds dollars go somewhere else.
# disneyland several times past 3 decades. visit, sensed employees disgruntled unhappy. smiles staff. addition, staff prowling people crossing ropes fantasmic on. need fastpass enter watch fan tasmic show everyone situated tons space paying customers without fastpass? see attached picture. whole show, entire space unoccupied 5 8 yr olds next us straining catch glimpse.if wanna pay $129 stand line hours ride average 9 rides last 3 11 minute, place you. disneyland become greedy overcrowd double capacity make money without care customers. ridiculous minimal places sit rest large park. highly recommend universal studios vip pass mess.
# partner paid $149 tickets park partner wanted see original disney castle.when paying tickets nothing mentioned couple issues had.firstly walked tried take photo using selfie stick told either throw away take back car hotel banned. leave come back again.then finally got back saw countless people cameras selfie sticks annoying, annoying pre telling us paying castle even visible working something. wooden panels castle painted paid full price partial access activities available us.we told left park another la holiday wasted $300.disney unacceptable true disappointment good thing breakfast carnation cafe staff superb apple cinnamon pancakes die for.all expensive disappointing day thanks disney pre advising people gate works carried out.

# %% [markdown]
# ##Text EDA on the California low rating Data

# %% [markdown]
# ## Most common words

# %%
myTable = df_California_low['Review_Text'].str.split(expand=True).stack().value_counts()
myTable[0:20] # too cool!
# Out:
# park          1351
# disney        1133
# get           1064
# disneyland    1048
# rides          972
# people         839
# go             785
# day            760
# would          735
# time           700
# one            698
# ride           693
# line           652
# wait           565
# many           520
# even           509
# like           501
# place          466
# us             444
# went           439
# Name: count, dtype: int64

# %%
x = df_California_low['Review_Text'].str.split(expand=True).stack().value_counts()
x = pd.DataFrame(x)
# reset the index
x.reset_index(inplace=True)
# rename the columns
x.rename(columns={x.columns[0]:'word', x.columns[1]:'frequency'}, inplace=True)
x.head()
# Out:
#          word  frequency
# 0        park       1351
# 1      disney       1133
# 2         get       1064
# 3  disneyland       1048
# 4       rides        972

# %%
x = x[0:20] # wanna play? change the 20 to 10 or 30 and see what happens...
            # you need to run the previous cell first
x.plot(x='word', y='frequency')
plt.xticks(np.arange(len(x)), x['word'], rotation=90)
plt.suptitle('Top Words in DisneyLand California low rating Review')
plt.show()

# %% [markdown]
# ## Word Cloud

# %%
from wordcloud import WordCloud

# Generate a word cloud image
wordcloud = WordCloud().generate(' '.join(df_California_low['Review_Text']))

# # Display the generated image:
# # the matplotlib way:
# import matplotlib.pyplot as plt
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(' '.join(df_California_low['Review_Text']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ##Tokenizer

# %%
df_California_low['Review_Text'] = df_California_low.apply(lambda row: nltk.word_tokenize(row['Review_Text']), axis=1)
df_California_low.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  669660324       2    2018-10     United States
# 1  669505006       1    missing     United States
# 2  668730191       2     2019-4    United Kingdom
# 3  667955757       1     2019-1         Australia
# 4  664615049       1     2019-4         Australia
#
#                                          Review_Text                 Branch  \
# 0  [doubt, legendary, place, dont, think, worth, ...  Disneyland_California
# 1  [disneyland, several, times, past, 3, decades,...  Disneyland_California
# 2  [partner, paid, $, 149, tickets, park, partner...  Disneyland_California
# 3  [comes, happy, place, ,, welcome, ., well, wal...  Disneyland_California
# 4  [really, disappointed, disneyland.old, ,, tire...  Disneyland_California
#
#    New_Rating
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
print(df_California_low['Review_Text'][0])
print(df_California_low['Review_Text'][1])
print(df_California_low['Review_Text'][2])
# Out:
# ['doubt', 'legendary', 'place', 'dont', 'think', 'worth', 'money', 'headache', 'overcrowding', 'overpriced', 'everything', '.', 'disney', 'continues', 'raise', 'price', 'admission', 'crowds', 'ridiculous', 'every', 'single', 'day', '.', 'plenty', 'things', 'socal', 'cheap', 'free', '.', 'save', 'family', 'hundreds', 'dollars', 'go', 'somewhere', 'else', '.']
# ['disneyland', 'several', 'times', 'past', '3', 'decades', '.', 'visit', ',', 'sensed', 'employees', 'disgruntled', 'unhappy', '.', 'smiles', 'staff', '.', 'addition', ',', 'staff', 'prowling', 'people', 'crossing', 'ropes', 'fantasmic', 'on', '.', 'need', 'fastpass', 'enter', 'watch', 'fan', 'tasmic', 'show', 'everyone', 'situated', 'tons', 'space', 'paying', 'customers', 'without', 'fastpass', '?', 'see', 'attached', 'picture', '.', 'whole', 'show', ',', 'entire', 'space', 'unoccupied', '5', '8', 'yr', 'olds', 'next', 'us', 'straining', 'catch', 'glimpse.if', 'wan', 'na', 'pay', '$', '129', 'stand', 'line', 'hours', 'ride', 'average', '9', 'rides', 'last', '3', '11', 'minute', ',', 'place', 'you', '.', 'disneyland', 'become', 'greedy', 'overcrowd', 'double', 'capacity', 'make', 'money', 'without', 'care', 'customers', '.', 'ridiculous', 'minimal', 'places', 'sit', 'rest', 'large', 'park', '.', 'highly', 'recommend', 'universal', 'studios', 'vip', 'pass', 'mess', '.']
# ['partner', 'paid', '$', '149', 'tickets', 'park', 'partner', 'wanted', 'see', 'original', 'disney', 'castle.when', 'paying', 'tickets', 'nothing', 'mentioned', 'couple', 'issues', 'had.firstly', 'walked', 'tried', 'take', 'photo', 'using', 'selfie', 'stick', 'told', 'either', 'throw', 'away', 'take', 'back', 'car', 'hotel', 'banned', '.', 'leave', 'come', 'back', 'again.then', 'finally', 'got', 'back', 'saw', 'countless', 'people', 'cameras', 'selfie', 'sticks', 'annoying', ',', 'annoying', 'pre', 'telling', 'us', 'paying', 'castle', 'even', 'visible', 'working', 'something', '.', 'wooden', 'panels', 'castle', 'painted', 'paid', 'full', 'price', 'partial', 'access', 'activities', 'available', 'us.we', 'told', 'left', 'park', 'another', 'la', 'holiday', 'wasted', '$', '300.disney', 'unacceptable', 'true', 'disappointment', 'good', 'thing', 'breakfast', 'carnation', 'cafe', 'staff', 'superb', 'apple', 'cinnamon', 'pancakes', 'die', 'for.all', 'expensive', 'disappointing', 'day', 'thanks', 'disney', 'pre', 'advising', 'people', 'gate', 'works', 'carried', 'out', '.']

# %% [markdown]
# ## Lexicon Normalization

# %% [markdown]
# ###Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# this is the function we will use
ps = PorterStemmer()

filtered_sent = df_California_low['Review_Text'][1]

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['disneyland', 'several', 'times', 'past', '3', 'decades', '.', 'visit', ',', 'sensed', 'employees', 'disgruntled', 'unhappy', '.', 'smiles', 'staff', '.', 'addition', ',', 'staff', 'prowling', 'people', 'crossing', 'ropes', 'fantasmic', 'on', '.', 'need', 'fastpass', 'enter', 'watch', 'fan', 'tasmic', 'show', 'everyone', 'situated', 'tons', 'space', 'paying', 'customers', 'without', 'fastpass', '?', 'see', 'attached', 'picture', '.', 'whole', 'show', ',', 'entire', 'space', 'unoccupied', '5', '8', 'yr', 'olds', 'next', 'us', 'straining', 'catch', 'glimpse.if', 'wan', 'na', 'pay', '$', '129', 'stand', 'line', 'hours', 'ride', 'average', '9', 'rides', 'last', '3', '11', 'minute', ',', 'place', 'you', '.', 'disneyland', 'become', 'greedy', 'overcrowd', 'double', 'capacity', 'make', 'money', 'without', 'care', 'customers', '.', 'ridiculous', 'minimal', 'places', 'sit', 'rest', 'large', 'park', '.', 'highly', 'recommend', 'universal', 'studios', 'vip', 'pass', 'mess', '.']
# Stemmed Sentence: ['disneyland', 'sever', 'time', 'past', '3', 'decad', '.', 'visit', ',', 'sens', 'employe', 'disgruntl', 'unhappi', '.', 'smile', 'staff', '.', 'addit', ',', 'staff', 'prowl', 'peopl', 'cross', 'rope', 'fantasm', 'on', '.', 'need', 'fastpass', 'enter', 'watch', 'fan', 'tasmic', 'show', 'everyon', 'situat', 'ton', 'space', 'pay', 'custom', 'without', 'fastpass', '?', 'see', 'attach', 'pictur', '.', 'whole', 'show', ',', 'entir', 'space', 'unoccupi', '5', '8', 'yr', 'old', 'next', 'us', 'strain', 'catch', 'glimpse.if', 'wan', 'na', 'pay', '$', '129', 'stand', 'line', 'hour', 'ride', 'averag', '9', 'ride', 'last', '3', '11', 'minut', ',', 'place', 'you', '.', 'disneyland', 'becom', 'greedi', 'overcrowd', 'doubl', 'capac', 'make', 'money', 'without', 'care', 'custom', '.', 'ridicul', 'minim', 'place', 'sit', 'rest', 'larg', 'park', '.', 'highli', 'recommend', 'univers', 'studio', 'vip', 'pass', 'mess', '.']

# %%
df_California_low['Stemmed'] = df_California_low['Review_Text'].apply(lambda x: [ps.stem(y) for y in x]) # Stem every word.

# %%
# check your work!
print(df_California_low['Review_Text'][0]) # reported
print(df_California_low['Stemmed'][0]) # report

print(df_California_low['Review_Text'][10]) # note the difference between inches, reported, covered
print(df_California_low['Stemmed'][10]) # inch, report, cover
# Out:
# ['doubt', 'legendary', 'place', 'dont', 'think', 'worth', 'money', 'headache', 'overcrowding', 'overpriced', 'everything', '.', 'disney', 'continues', 'raise', 'price', 'admission', 'crowds', 'ridiculous', 'every', 'single', 'day', '.', 'plenty', 'things', 'socal', 'cheap', 'free', '.', 'save', 'family', 'hundreds', 'dollars', 'go', 'somewhere', 'else', '.']
# ['doubt', 'legendari', 'place', 'dont', 'think', 'worth', 'money', 'headach', 'overcrowd', 'overpr', 'everyth', '.', 'disney', 'continu', 'rais', 'price', 'admiss', 'crowd', 'ridicul', 'everi', 'singl', 'day', '.', 'plenti', 'thing', 'socal', 'cheap', 'free', '.', 'save', 'famili', 'hundr', 'dollar', 'go', 'somewher', 'els', '.']
# ['visited', 'disneyland', 'october', 'november', '2018we', 'bought', '4', ',', '5', 'day', 'passes', 'online', 'due', 'error', 'online', ',', 'unable', 'buy', 'canadian', 'rate', 'discount', 'charged', 'full', 'rate', '(', 'about', '$', '400', 'error', ')', 'called', 'disneyland', 'told', 'happened', 'online', '.', 'talked', '3', 'different', 'service', 'agents', 'different', 'times', '.', '(', '2', 'agents', 'rude', ',', 'last', 'nice', ')', 'would', 'say', 'sorry', ',', 'last', 'agent', 'said', 'try', 'credit', 'card', 'company', 'talked', 'front', 'gate', 'customer', 'service.mastercard', 'said', 'transaction', 'already', 'processed', 'went', 'front', 'gate', '...', 'sorry', 'nothing', 'done', 'here', ',', 'go', 'inside', 'talk', 'customer', 'relationstalked', 'customer', 'relations', ',', 'sorry', 'anything', 'another', '2', 'agents', 'disneyland', '50', 'times', 'since', '1977', ',', 'never', 'go', 'backthe', 'whole', 'experience', 'ruined', 'trip', ',', 'warned', ':', 'disney', 'corporation', 'cares', 'bottom', 'line']
# ['visit', 'disneyland', 'octob', 'novemb', '2018we', 'bought', '4', ',', '5', 'day', 'pass', 'onlin', 'due', 'error', 'onlin', ',', 'unabl', 'buy', 'canadian', 'rate', 'discount', 'charg', 'full', 'rate', '(', 'about', '$', '400', 'error', ')', 'call', 'disneyland', 'told', 'happen', 'onlin', '.', 'talk', '3', 'differ', 'servic', 'agent', 'differ', 'time', '.', '(', '2', 'agent', 'rude', ',', 'last', 'nice', ')', 'would', 'say', 'sorri', ',', 'last', 'agent', 'said', 'tri', 'credit', 'card', 'compani', 'talk', 'front', 'gate', 'custom', 'service.mastercard', 'said', 'transact', 'alreadi', 'process', 'went', 'front', 'gate', '...', 'sorri', 'noth', 'done', 'here', ',', 'go', 'insid', 'talk', 'custom', 'relationstalk', 'custom', 'relat', ',', 'sorri', 'anyth', 'anoth', '2', 'agent', 'disneyland', '50', 'time', 'sinc', '1977', ',', 'never', 'go', 'backth', 'whole', 'experi', 'ruin', 'trip', ',', 'warn', ':', 'disney', 'corpor', 'care', 'bottom', 'line']

# %% [markdown]
# # Paris Disneyland Analysis

# %%
# one line of code! we made a new column and populated it
df_Paris['New_Rating'] = np.where(df_Paris['Rating'] < 3, 0, 1)

df_Paris.head()
# Out:
# <ipython-input-66-9ca285fa12b3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Paris['New_Rating'] = np.where(df_Paris['Rating'] < 3, 0, 1)
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 29026  670721950       5     2019-3  United Arab Emirates
# 29027  670686565       4     2018-6        United Kingdom
# 29028  670606796       5     2019-4        United Kingdom
# 29029  670586937       4     2019-4             Australia
# 29030  670535589       5    missing                France
#
#                                              Review_Text            Branch  \
# 29026  We've been to Disneyland Hongkong and Tokyo, s...  Disneyland_Paris
# 29027  I went to Disneyland Paris in April 2018 on Ea...  Disneyland_Paris
# 29028  What a fantastic place, the queues were decent...  Disneyland_Paris
# 29029  We didn't realise it was school holidays when ...  Disneyland_Paris
# 29030  A Trip to Disney makes you all warm and fuzzy ...  Disneyland_Paris
#
#        New_Rating
# 29026           1
# 29027           1
# 29028           1
# 29029           1
# 29030           1

# %% [markdown]
# ## Exploring the text data

# %% [markdown]
# ###High Rating Reviews Analysis for Paris DisneyLand

# %%
df_Paris_high = df_Paris[df_Paris['New_Rating']==1]
df_Paris_high.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11758 entries, 29026 to 42655
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          11758 non-null  int64
#  1   Rating             11758 non-null  int64
#  2   Year_Month         11758 non-null  object
#  3   Reviewer_Location  11758 non-null  object
#  4   Review_Text        11758 non-null  object
#  5   Branch             11758 non-null  object
#  6   New_Rating         11758 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 734.9+ KB

# %%
df_Paris_high.head()
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 29026  670721950       5     2019-3  United Arab Emirates
# 29027  670686565       4     2018-6        United Kingdom
# 29028  670606796       5     2019-4        United Kingdom
# 29029  670586937       4     2019-4             Australia
# 29030  670535589       5    missing                France
#
#                                              Review_Text            Branch  \
# 29026  We've been to Disneyland Hongkong and Tokyo, s...  Disneyland_Paris
# 29027  I went to Disneyland Paris in April 2018 on Ea...  Disneyland_Paris
# 29028  What a fantastic place, the queues were decent...  Disneyland_Paris
# 29029  We didn't realise it was school holidays when ...  Disneyland_Paris
# 29030  A Trip to Disney makes you all warm and fuzzy ...  Disneyland_Paris
#
#        New_Rating
# 29026           1
# 29027           1
# 29028           1
# 29029           1
# 29030           1

# %%
print(df_Paris_high.index)
# Out:
# Index([29026, 29027, 29028, 29029, 29030, 29031, 29032, 29033, 29035, 29036,
#        ...
#        42645, 42646, 42648, 42649, 42650, 42651, 42652, 42653, 42654, 42655],
#       dtype='int64', length=11758)

# %%
df_Paris_high = df_Paris_high.reset_index(drop=True)

# %%
print(df_Paris_high['Review_Text'][0])
print(df_Paris_high['Review_Text'][1])
print(df_Paris_high['Review_Text'][2])
# Out:
# We've been to Disneyland Hongkong and Tokyo, so far this one is the best. We're looking forward to visit the biggest one in Orlando. 1 day is not enough, it is recommended to stay in Disney Hotel   Resort so you can enjoy the fast track.. save huge amount of time.. if you're not staying there, plan and strategize your visit by getting all the fast track passes from kiosk nearby the attraction; then come back when it's time for your ride. The projection and fireworks show are out of this world!!
# I went to Disneyland Paris in April 2018 on Easter weekend, I know it says June 2018 but I can't choose a date before then, and I loved it, me and my mum went and as I have autism we managed to get a disability pass for both parks. Disney are excellent with disability access and cater to all types of disabilities, both visible (wheelchair users, etc.) and invisible (autism, etc.), we managed to get on a lot of rides because with the pass you don't queue in the normal queue but the entrance for disabilities. I can only fault one thing when I went we met Spider man and had photos taken but you have to pay for the photos and they are very expensive, even to just pay for one photo. The food wasn't spectacular but it was edible and nice, there is a variety of food outlets so there was plenty of choice. I would loved to go again in Halloween or Christmas but if not I would just love to go again.
# What a fantastic place, the queues were decent as this is the best time of year to go apparently, we managed to see almost everything, I was a bit disappointed the Haunted Mansion wasn   t open but it can   t be helped! The fireworks were amazing and the parade was so entertaining!A definite must for all Disney lovers!

# %% [markdown]
# ##Lowercase

# %%
df_Paris_high['Review_Text'] = df_Paris_high['Review_Text'].str.lower()
df_Paris_high.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670721950       5     2019-3  United Arab Emirates
# 1  670686565       4     2018-6        United Kingdom
# 2  670606796       5     2019-4        United Kingdom
# 3  670586937       4     2019-4             Australia
# 4  670535589       5    missing                France
#
#                                          Review_Text            Branch  \
# 0  we've been to disneyland hongkong and tokyo, s...  Disneyland_Paris
# 1  i went to disneyland paris in april 2018 on ea...  Disneyland_Paris
# 2  what a fantastic place, the queues were decent...  Disneyland_Paris
# 3  we didn't realise it was school holidays when ...  Disneyland_Paris
# 4  a trip to disney makes you all warm and fuzzy ...  Disneyland_Paris
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
print(df_Paris_high['Review_Text'][0])
print(df_Paris_high['Review_Text'][1])
print(df_Paris_high['Review_Text'][2])
# Out:
# we've been to disneyland hongkong and tokyo, so far this one is the best. we're looking forward to visit the biggest one in orlando. 1 day is not enough, it is recommended to stay in disney hotel   resort so you can enjoy the fast track.. save huge amount of time.. if you're not staying there, plan and strategize your visit by getting all the fast track passes from kiosk nearby the attraction; then come back when it's time for your ride. the projection and fireworks show are out of this world!!
# i went to disneyland paris in april 2018 on easter weekend, i know it says june 2018 but i can't choose a date before then, and i loved it, me and my mum went and as i have autism we managed to get a disability pass for both parks. disney are excellent with disability access and cater to all types of disabilities, both visible (wheelchair users, etc.) and invisible (autism, etc.), we managed to get on a lot of rides because with the pass you don't queue in the normal queue but the entrance for disabilities. i can only fault one thing when i went we met spider man and had photos taken but you have to pay for the photos and they are very expensive, even to just pay for one photo. the food wasn't spectacular but it was edible and nice, there is a variety of food outlets so there was plenty of choice. i would loved to go again in halloween or christmas but if not i would just love to go again.
# what a fantastic place, the queues were decent as this is the best time of year to go apparently, we managed to see almost everything, i was a bit disappointed the haunted mansion wasn   t open but it can   t be helped! the fireworks were amazing and the parade was so entertaining!a definite must for all disney lovers!

# %% [markdown]
# ##Strip funky characters (!,~-@$% etc)

# %%
# Convert all entries in the 'Review_Text' column to strings
df_Paris_high["Review_Text"] = df_Paris_high["Review_Text"].astype(str)

# Remove any funky characters with a blank, including handling extra spaces and trimming
df_Paris_high['Review_Text'] = df_Paris_high['Review_Text'].str.replace('[^a-zA-Z ]', '', regex=True).str.replace(' +', ' ', regex=True).str.strip()

# Display the cleaned DataFrame
df_Paris_high.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670721950       5     2019-3  United Arab Emirates
# 1  670686565       4     2018-6        United Kingdom
# 2  670606796       5     2019-4        United Kingdom
# 3  670586937       4     2019-4             Australia
# 4  670535589       5    missing                France
#
#                                          Review_Text            Branch  \
# 0  weve been to disneyland hongkong and tokyo so ...  Disneyland_Paris
# 1  i went to disneyland paris in april on easter ...  Disneyland_Paris
# 2  what a fantastic place the queues were decent ...  Disneyland_Paris
# 3  we didnt realise it was school holidays when w...  Disneyland_Paris
# 4  a trip to disney makes you all warm and fuzzy ...  Disneyland_Paris
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
df_Paris_high['Review_Text'] = df_Paris_high['Review_Text'].str.replace('[^A-z ]','').str.replace(' +',' ').str.strip()
df_Paris_high.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670721950       5     2019-3  United Arab Emirates
# 1  670686565       4     2018-6        United Kingdom
# 2  670606796       5     2019-4        United Kingdom
# 3  670586937       4     2019-4             Australia
# 4  670535589       5    missing                France
#
#                                          Review_Text            Branch  \
# 0  weve been to disneyland hongkong and tokyo so ...  Disneyland_Paris
# 1  i went to disneyland paris in april on easter ...  Disneyland_Paris
# 2  what a fantastic place the queues were decent ...  Disneyland_Paris
# 3  we didnt realise it was school holidays when w...  Disneyland_Paris
# 4  a trip to disney makes you all warm and fuzzy ...  Disneyland_Paris
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
print(df_Paris_high['Review_Text'][0])
print(df_Paris_high['Review_Text'][1])
print(df_Paris_high['Review_Text'][2])
# Out:
# weve been to disneyland hongkong and tokyo so far this one is the best were looking forward to visit the biggest one in orlando day is not enough it is recommended to stay in disney hotel resort so you can enjoy the fast track save huge amount of time if youre not staying there plan and strategize your visit by getting all the fast track passes from kiosk nearby the attraction then come back when its time for your ride the projection and fireworks show are out of this world
# i went to disneyland paris in april on easter weekend i know it says june but i cant choose a date before then and i loved it me and my mum went and as i have autism we managed to get a disability pass for both parks disney are excellent with disability access and cater to all types of disabilities both visible wheelchair users etc and invisible autism etc we managed to get on a lot of rides because with the pass you dont queue in the normal queue but the entrance for disabilities i can only fault one thing when i went we met spider man and had photos taken but you have to pay for the photos and they are very expensive even to just pay for one photo the food wasnt spectacular but it was edible and nice there is a variety of food outlets so there was plenty of choice i would loved to go again in halloween or christmas but if not i would just love to go again
# what a fantastic place the queues were decent as this is the best time of year to go apparently we managed to see almost everything i was a bit disappointed the haunted mansion wasn t open but it can t be helped the fireworks were amazing and the parade was so entertaininga definite must for all disney lovers

# %% [markdown]
# ##Stop words

# %%
import nltk
from nltk.corpus import stopwords


nltk.download('stopwords') # this makes sure these are downloaded if you haven't already!
print(stopwords.words('english'))

stop = stopwords.words('english') # see why it's important to turn everything lower case? all of your stopwords are!
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_Paris_high['Review_Text'] = df_Paris_high['Review_Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
df_Paris_high.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670721950       5     2019-3  United Arab Emirates
# 1  670686565       4     2018-6        United Kingdom
# 2  670606796       5     2019-4        United Kingdom
# 3  670586937       4     2019-4             Australia
# 4  670535589       5    missing                France
#
#                                          Review_Text            Branch  \
# 0  we've disneyland hongkong tokyo, far one best....  Disneyland_Paris
# 1  went disneyland paris april 2018 easter weeken...  Disneyland_Paris
# 2  fantastic place, queues decent best time year ...  Disneyland_Paris
# 3  realise school holidays went, consequently ext...  Disneyland_Paris
# 4  trip disney makes warm fuzzy actual kid again....  Disneyland_Paris
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
print(df_Paris_high['Review_Text'][0])
print(df_Paris_high['Review_Text'][1])
print(df_Paris_high['Review_Text'][2])
# Out:
# we've disneyland hongkong tokyo, far one best. we're looking forward visit biggest one orlando. 1 day enough, recommended stay disney hotel resort enjoy fast track.. save huge amount time.. staying there, plan strategize visit getting fast track passes kiosk nearby attraction; come back time ride. projection fireworks show world!!
# went disneyland paris april 2018 easter weekend, know says june 2018 can't choose date then, loved it, mum went autism managed get disability pass parks. disney excellent disability access cater types disabilities, visible (wheelchair users, etc.) invisible (autism, etc.), managed get lot rides pass queue normal queue entrance disabilities. fault one thing went met spider man photos taken pay photos expensive, even pay one photo. food spectacular edible nice, variety food outlets plenty choice. would loved go halloween christmas would love go again.
# fantastic place, queues decent best time year go apparently, managed see almost everything, bit disappointed haunted mansion open helped! fireworks amazing parade entertaining!a definite must disney lovers!

# %% [markdown]
# ##Text EDA on the Paris high rating Data

# %% [markdown]
# ## Most common words

# %%
myTable = df_Paris_high['Review_Text'].str.split(expand=True).stack().value_counts()
myTable[0:20] # too cool!
# Out:
# park          12278
# disney        11826
# rides          9273
# get            7475
# time           7318
# disneyland     6040
# day            5977
# one            5931
# go             5901
# would          5393
# food           4550
# good           4505
# great          4498
# really         4493
# ride           3848
# see            3747
# went           3632
# paris          3585
# much           3494
# also           3493
# Name: count, dtype: int64

# %%
x = df_Paris_high['Review_Text'].str.split(expand=True).stack().value_counts()
x = pd.DataFrame(x)
# reset the index
x.reset_index(inplace=True)
# rename the columns
x.rename(columns={x.columns[0]:'word', x.columns[1]:'frequency'}, inplace=True)
x.head()
# Out:
#      word  frequency
# 0    park      12278
# 1  disney      11826
# 2   rides       9273
# 3     get       7475
# 4    time       7318

# %%
x = x[0:20] # wanna play? change the 20 to 10 or 30 and see what happens...
            # you need to run the previous cell first
x.plot(x='word', y='frequency')
plt.xticks(np.arange(len(x)), x['word'], rotation=90)
plt.suptitle('Top Words in DisneyLand Paris high rated Review')
plt.show()

# %% [markdown]
# ## Word Cloud

# %%
from wordcloud import WordCloud

# Generate a word cloud image
wordcloud = WordCloud().generate(' '.join(df_Paris_high['Review_Text']))

# # Display the generated image:
# # the matplotlib way:
# import matplotlib.pyplot as plt
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(' '.join(df_Paris_high['Review_Text']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ##Tokenizer

# %%
df_Paris_high['Review_Text'] = df_Paris_high.apply(lambda row: nltk.word_tokenize(row['Review_Text']), axis=1)
df_Paris_high.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670721950       5     2019-3  United Arab Emirates
# 1  670686565       4     2018-6        United Kingdom
# 2  670606796       5     2019-4        United Kingdom
# 3  670586937       4     2019-4             Australia
# 4  670535589       5    missing                France
#
#                                          Review_Text            Branch  \
# 0  [we, 've, disneyland, hongkong, tokyo, ,, far,...  Disneyland_Paris
# 1  [went, disneyland, paris, april, 2018, easter,...  Disneyland_Paris
# 2  [fantastic, place, ,, queues, decent, best, ti...  Disneyland_Paris
# 3  [realise, school, holidays, went, ,, consequen...  Disneyland_Paris
# 4  [trip, disney, makes, warm, fuzzy, actual, kid...  Disneyland_Paris
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
print(df_Paris_high['Review_Text'][0])
print(df_Paris_high['Review_Text'][1])
print(df_Paris_high['Review_Text'][2])
# Out:
# ['we', "'ve", 'disneyland', 'hongkong', 'tokyo', ',', 'far', 'one', 'best', '.', 'we', "'re", 'looking', 'forward', 'visit', 'biggest', 'one', 'orlando', '.', '1', 'day', 'enough', ',', 'recommended', 'stay', 'disney', 'hotel', 'resort', 'enjoy', 'fast', 'track', '..', 'save', 'huge', 'amount', 'time', '..', 'staying', 'there', ',', 'plan', 'strategize', 'visit', 'getting', 'fast', 'track', 'passes', 'kiosk', 'nearby', 'attraction', ';', 'come', 'back', 'time', 'ride', '.', 'projection', 'fireworks', 'show', 'world', '!', '!']
# ['went', 'disneyland', 'paris', 'april', '2018', 'easter', 'weekend', ',', 'know', 'says', 'june', '2018', 'ca', "n't", 'choose', 'date', 'then', ',', 'loved', 'it', ',', 'mum', 'went', 'autism', 'managed', 'get', 'disability', 'pass', 'parks', '.', 'disney', 'excellent', 'disability', 'access', 'cater', 'types', 'disabilities', ',', 'visible', '(', 'wheelchair', 'users', ',', 'etc', '.', ')', 'invisible', '(', 'autism', ',', 'etc', '.', ')', ',', 'managed', 'get', 'lot', 'rides', 'pass', 'queue', 'normal', 'queue', 'entrance', 'disabilities', '.', 'fault', 'one', 'thing', 'went', 'met', 'spider', 'man', 'photos', 'taken', 'pay', 'photos', 'expensive', ',', 'even', 'pay', 'one', 'photo', '.', 'food', 'spectacular', 'edible', 'nice', ',', 'variety', 'food', 'outlets', 'plenty', 'choice', '.', 'would', 'loved', 'go', 'halloween', 'christmas', 'would', 'love', 'go', 'again', '.']
# ['fantastic', 'place', ',', 'queues', 'decent', 'best', 'time', 'year', 'go', 'apparently', ',', 'managed', 'see', 'almost', 'everything', ',', 'bit', 'disappointed', 'haunted', 'mansion', 'open', 'helped', '!', 'fireworks', 'amazing', 'parade', 'entertaining', '!', 'a', 'definite', 'must', 'disney', 'lovers', '!']

# %% [markdown]
# ## Lexicon Normalization

# %% [markdown]
# ###Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# this is the function we will use
ps = PorterStemmer()

filtered_sent = df_Paris_high['Review_Text'][1]

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['went', 'disneyland', 'paris', 'april', '2018', 'easter', 'weekend', ',', 'know', 'says', 'june', '2018', 'ca', "n't", 'choose', 'date', 'then', ',', 'loved', 'it', ',', 'mum', 'went', 'autism', 'managed', 'get', 'disability', 'pass', 'parks', '.', 'disney', 'excellent', 'disability', 'access', 'cater', 'types', 'disabilities', ',', 'visible', '(', 'wheelchair', 'users', ',', 'etc', '.', ')', 'invisible', '(', 'autism', ',', 'etc', '.', ')', ',', 'managed', 'get', 'lot', 'rides', 'pass', 'queue', 'normal', 'queue', 'entrance', 'disabilities', '.', 'fault', 'one', 'thing', 'went', 'met', 'spider', 'man', 'photos', 'taken', 'pay', 'photos', 'expensive', ',', 'even', 'pay', 'one', 'photo', '.', 'food', 'spectacular', 'edible', 'nice', ',', 'variety', 'food', 'outlets', 'plenty', 'choice', '.', 'would', 'loved', 'go', 'halloween', 'christmas', 'would', 'love', 'go', 'again', '.']
# Stemmed Sentence: ['went', 'disneyland', 'pari', 'april', '2018', 'easter', 'weekend', ',', 'know', 'say', 'june', '2018', 'ca', "n't", 'choos', 'date', 'then', ',', 'love', 'it', ',', 'mum', 'went', 'autism', 'manag', 'get', 'disabl', 'pass', 'park', '.', 'disney', 'excel', 'disabl', 'access', 'cater', 'type', 'disabl', ',', 'visibl', '(', 'wheelchair', 'user', ',', 'etc', '.', ')', 'invis', '(', 'autism', ',', 'etc', '.', ')', ',', 'manag', 'get', 'lot', 'ride', 'pass', 'queue', 'normal', 'queue', 'entranc', 'disabl', '.', 'fault', 'one', 'thing', 'went', 'met', 'spider', 'man', 'photo', 'taken', 'pay', 'photo', 'expens', ',', 'even', 'pay', 'one', 'photo', '.', 'food', 'spectacular', 'edibl', 'nice', ',', 'varieti', 'food', 'outlet', 'plenti', 'choic', '.', 'would', 'love', 'go', 'halloween', 'christma', 'would', 'love', 'go', 'again', '.']

# %%
df_Paris_high['Stemmed'] = df_Paris_high['Review_Text'].apply(lambda x: [ps.stem(y) for y in x]) # Stem every word.

# %%
# check your work!
print(df_Paris_high['Review_Text'][0]) # reported
print(df_Paris_high['Stemmed'][0]) # report

print(df_Paris_high['Review_Text'][10]) # note the difference between inches, reported, covered
print(df_Paris_high['Stemmed'][10]) # inch, report, cover
# Out:
# ['we', "'ve", 'disneyland', 'hongkong', 'tokyo', ',', 'far', 'one', 'best', '.', 'we', "'re", 'looking', 'forward', 'visit', 'biggest', 'one', 'orlando', '.', '1', 'day', 'enough', ',', 'recommended', 'stay', 'disney', 'hotel', 'resort', 'enjoy', 'fast', 'track', '..', 'save', 'huge', 'amount', 'time', '..', 'staying', 'there', ',', 'plan', 'strategize', 'visit', 'getting', 'fast', 'track', 'passes', 'kiosk', 'nearby', 'attraction', ';', 'come', 'back', 'time', 'ride', '.', 'projection', 'fireworks', 'show', 'world', '!', '!']
# ['we', "'ve", 'disneyland', 'hongkong', 'tokyo', ',', 'far', 'one', 'best', '.', 'we', "'re", 'look', 'forward', 'visit', 'biggest', 'one', 'orlando', '.', '1', 'day', 'enough', ',', 'recommend', 'stay', 'disney', 'hotel', 'resort', 'enjoy', 'fast', 'track', '..', 'save', 'huge', 'amount', 'time', '..', 'stay', 'there', ',', 'plan', 'strateg', 'visit', 'get', 'fast', 'track', 'pass', 'kiosk', 'nearbi', 'attract', ';', 'come', 'back', 'time', 'ride', '.', 'project', 'firework', 'show', 'world', '!', '!']
# ['second', 'time', 'disney', 'experience', 'almost', 'great', '.', 'thing', ',', 'space', 'mountain', 'ha', 'problem', 'first', 'morning', 'closed', 'rest', 'day', 'next', 'day', '.']
# ['second', 'time', 'disney', 'experi', 'almost', 'great', '.', 'thing', ',', 'space', 'mountain', 'ha', 'problem', 'first', 'morn', 'close', 'rest', 'day', 'next', 'day', '.']

# %% [markdown]
# ###Low Rating Reviews Analysis for California DisneyLand

# %%
df_Paris_low = df_Paris[df_Paris['New_Rating']==0]
df_Paris_low.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1872 entries, 29034 to 42647
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          1872 non-null   int64
#  1   Rating             1872 non-null   int64
#  2   Year_Month         1872 non-null   object
#  3   Reviewer_Location  1872 non-null   object
#  4   Review_Text        1872 non-null   object
#  5   Branch             1872 non-null   object
#  6   New_Rating         1872 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 117.0+ KB

# %%
df_Paris_low.head()
# Out:
#        Review_ID  Rating Year_Month Reviewer_Location  \
# 29034  670216406       2     2019-4            Greece
# 29043  669337300       1     2019-4            Greece
# 29047  669121201       2     2019-4       Switzerland
# 29053  668207242       1     2019-4    United Kingdom
# 29058  668123744       2     2019-4    United Kingdom
#
#                                              Review_Text            Branch  \
# 29034  We booked tickets on line for Disneyland, this...  Disneyland_Paris
# 29043  Why they selling fastpass tickets without have...  Disneyland_Paris
# 29047  We went to Disneyland Paris during the Easter ...  Disneyland_Paris
# 29053  Its a shame this park carry the name Disney......  Disneyland_Paris
# 29058  I know Disneyland is a money machine but hadn ...  Disneyland_Paris
#
#        New_Rating
# 29034           0
# 29043           0
# 29047           0
# 29053           0
# 29058           0

# %%
print(df_Paris_low.index)
# Out:
# Index([29034, 29043, 29047, 29053, 29058, 29064, 29065, 29067, 29074, 29078,
#        ...
#        42629, 42630, 42633, 42635, 42636, 42639, 42640, 42641, 42643, 42647],
#       dtype='int64', length=1872)

# %%
df_Paris_low = df_Paris_low.reset_index(drop=True)

# %%
print(df_Paris_low['Review_Text'][0])
print(df_Paris_low['Review_Text'][1])
print(df_Paris_low['Review_Text'][2])
# Out:
# We booked tickets on line for Disneyland, this is something I recommend, the lines were already long when we got there, so booking your tickets in advance does help.I was advised to buy a fast passes, but i decided not to, because it was not clear to me on the website if this also counted as an entrance ticket, meaning; a total price of 90 euro with entrancevinstead or 74 or 68 or an extra 90 euro's, depending on age of child.But even if we would have, the lines were long there as well, and also, what kind of system is this? People that do not have that much to spend will be held back, because people with money obviously can skip the lines...absolutely ridiculous.Getting something to eat was horrible, again lines everywhere...just to eat someting right...And don't get me started on the staff, trying to figure out the amount of 3 icecreams with a small casio computer, and not being able to, or very rude staff. Only 2 ladies were friendly, have to be honest. All in all, very disappointing, long waiting lines, not being able to sit somewhere like a human being, and bad service.Our kids were so disappointed that they wanted to leave.We even heard people saying: 'Never again'.Absolutely not worth the money.
# Why they selling fastpass tickets without have buy before the entrance tickets???  Any answer ???  Shame on you!!!   We came here from Greece until the entrance!!!  Avoid this place!!!
# We went to Disneyland Paris during the Easter break with family members who had come over from the States. As we had all experience Disneyland in Anaheim and Disneyworld in Orlando, perhaps our expectations were just too high. First off, the moving sidewalks from the parking lot to the park entrance were broken. Not a great first impression. Furthermore, there was a lot of gardening work ongoing when we arrived. Isn't Disney supposed to be magic, with everything looking in top shape and perfect? The security line moved, but was the first bottleneck. The second major bottleneck was to actually enter the park. As we had bought tickets online, we thought we would be able to enter the park fairly easily. However, there was pretty much mass chaos at the ticket check point, with many people jumping the queue and others just standing around. We eventually made it through and made our way to Fantasyland.We managed to ride a few rides, but when it came time to get on the Teacups, they had closed the ride. Not for the day, but for about 45 minutes to disperse the line. This caused many people just to loiter around the entrance, waiting for the ride to open again. Not great. We did manage to eat lunch  early  enough that we didn't have to wait a long time. However, the food that we got was not what we ordered. None of us had the wherewithal to go back and try to fix the order. so we just ate what we got. When it came time for ice cream, it took about 45 minutes just to get to the front of the line, and then another 10 minutes to process the order. This was because the staff at the counter were poorly trained, and only one person knew how to use the register, and others seemed like trainees. There were plenty of other foodcarts around the park that were empty. Not enough staff at the park to operate these. There were also plenty of rides (like Autopia and Dumbo) that were closed for renovation. Disneyland Paris does not carry the iconic felt mouse ears. We definitely won't be going back, and I can't recommend Disneyland Paris to anyone who is looking for a true Disney experience.

# %% [markdown]
# ##Lowercase

# %%
df_Paris_low['Review_Text'] = df_Paris_low['Review_Text'].str.lower()
df_Paris_low.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  
low.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  670216406       2     2019-4            Greece
# 1  669337300       1     2019-4            Greece
# 2  669121201       2     2019-4       Switzerland
# 3  668207242       1     2019-4    United Kingdom
# 4  668123744       2     2019-4    United Kingdom
#
#                                          Review_Text            Branch  \
# 0  we booked tickets on line for disneyland, this...  Disneyland_Paris
# 1  why they selling fastpass tickets without have...  Disneyland_Paris
# 2  we went to disneyland paris during the easter ...  Disneyland_Paris
# 3  its a shame this park carry the name disney......  Disneyland_Paris
# 4  i know disneyland is a money machine but hadn ...  Disneyland_Paris
#
#    New_Rating
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
print(df_Paris_low['Review_Text'][0])
print(df_Paris_low['Review_Text'][1])
print(df_Paris_low['Review_Text'][2])
# Out:
# we booked tickets on line for disneyland, this is something i recommend, the lines were already long when we got there, so booking your tickets in advance does help.i was advised to buy a fast passes, but i decided not to, because it was not clear to me on the website if this also counted as an entrance ticket, meaning; a total price of 90 euro with entrancevinstead or 74 or 68 or an extra 90 euro's, depending on age of child.but even if we would have, the lines were long there as well, and also, what kind of system is this? people that do not have that much to spend will be held back, because people with money obviously can skip the lines...absolutely ridiculous.getting something to eat was horrible, again lines everywhere...just to eat someting right...and don't get me started on the staff, trying to figure out the amount of 3 icecreams with a small casio computer, and not being able to, or very rude staff. only 2 ladies were friendly, have to be honest. all in all, very disappointing, long waiting lines, not being able to sit somewhere like a human being, and bad service.our kids were so disappointed that they wanted to leave.we even heard people saying: 'never again'.absolutely not worth the money.
# why they selling fastpass tickets without have buy before the entrance tickets???  any answer ???  shame on you!!!   we came here from greece until the entrance!!!  avoid this place!!!
# we went to disneyland paris during the easter break with family members who had come over from the states. as we had all experience disneyland in anaheim and disneyworld in orlando, perhaps our expectations were just too high. first off, the moving sidewalks from the parking lot to the park entrance were broken. not a great first impression. furthermore, there was a lot of gardening work ongoing when we arrived. isn't disney supposed to be magic, with everything looking in top shape and perfect? the security line moved, but was the first bottleneck. the second major bottleneck was to actually enter the park. as we had bought tickets online, we thought we would be able to enter the park fairly easily. however, there was pretty much mass chaos at the ticket check point, with many people jumping the queue and others just standing around. we eventually made it through and made our way to fantasyland.we managed to ride a few rides, but when it came time to get on the teacups, they had closed the ride. not for the day, but for about 45 minutes to disperse the line. this caused many people just to loiter around the entrance, waiting for the ride to open again. not great. we did manage to eat lunch  early  enough that we didn't have to wait a long time. however, the food that we got was not what we ordered. none of us had the wherewithal to go back and try to fix the order. so we just ate what we got. when it came time for ice cream, it took about 45 minutes just to get to the front of the line, and then another 10 minutes to process the order. this was because the staff at the counter were poorly trained, and only one person knew how to use the register, and others seemed like trainees. there were plenty of other foodcarts around the park that were empty. not enough staff at the park to operate these. there were also plenty of rides (like autopia and dumbo) that were closed for renovation. disneyland paris does not carry the iconic felt mouse ears. we definitely won't be going back, and i can't recommend disneyland paris to anyone who is looking for a true disney experience.

# %% [markdown]
# ##Stop words

# %%
import nltk
from nltk.corpus import stopwords


nltk.download('stopwords') # this makes sure these are downloaded if you haven't already!
print(stopwords.words('english'))

stop = stopwords.words('english') # see why it's important to turn everything lower case? all of your stopwords are!
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_Paris_low['Review_Text'] = df_Paris_low['Review_Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
df_Paris_low.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  670216406       2     2019-4            Greece
# 1  669337300       1     2019-4            Greece
# 2  669121201       2     2019-4       Switzerland
# 3  668207242       1     2019-4    United Kingdom
# 4  668123744       2     2019-4    United Kingdom
#
#                                          Review_Text            Branch  \
# 0  booked tickets line disneyland, something reco...  Disneyland_Paris
# 1  selling fastpass tickets without buy entrance ...  Disneyland_Paris
# 2  went disneyland paris easter break family memb...  Disneyland_Paris
# 3  shame park carry name disney... build place ye...  Disneyland_Paris
# 4  know disneyland money machine realised much se...  Disneyland_Paris
#
#    New_Rating
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
print(df_Paris_low['Review_Text'][0])
print(df_Paris_low['Review_Text'][1])
print(df_Paris_low['Review_Text'][2])
# Out:
# booked tickets line disneyland, something recommend, lines already long got there, booking tickets advance help.i advised buy fast passes, decided to, clear website also counted entrance ticket, meaning; total price 90 euro entrancevinstead 74 68 extra 90 euro's, depending age child.but even would have, lines long well, also, kind system this? people much spend held back, people money obviously skip lines...absolutely ridiculous.getting something eat horrible, lines everywhere...just eat someting right...and get started staff, trying figure amount 3 icecreams small casio computer, able to, rude staff. 2 ladies friendly, honest. all, disappointing, long waiting lines, able sit somewhere like human being, bad service.our kids disappointed wanted leave.we even heard people saying: 'never again'.absolutely worth money.
# selling fastpass tickets without buy entrance tickets??? answer ??? shame you!!! came greece entrance!!! avoid place!!!
# went disneyland paris easter break family members come states. experience disneyland anaheim disneyworld orlando, perhaps expectations high. first off, moving sidewalks parking lot park entrance broken. great first impression. furthermore, lot gardening work ongoing arrived. disney supposed magic, everything looking top shape perfect? security line moved, first bottleneck. second major bottleneck actually enter park. bought tickets online, thought would able enter park fairly easily. however, pretty much mass chaos ticket check point, many people jumping queue others standing around. eventually made made way fantasyland.we managed ride rides, came time get teacups, closed ride. day, 45 minutes disperse line. caused many people loiter around entrance, waiting ride open again. great. manage eat lunch early enough wait long time. however, food got ordered. none us wherewithal go back try fix order. ate got. came time ice cream, took 45 minutes get front line, another 10 minutes process order. staff counter poorly trained, one person knew use register, others seemed like trainees. plenty foodcarts around park empty. enough staff park operate these. also plenty rides (like autopia dumbo) closed renovation. disneyland paris carry iconic felt mouse ears. definitely going back, can't recommend disneyland paris anyone looking true disney experience.

# %% [markdown]
# ##Text EDA on the Paris low rating Data

# %% [markdown]
# ## Most common words

# %%
myTable = df_Paris_low['Review_Text'].str.split(expand=True).stack().value_counts()
myTable[0:20] # too cool!
# Out:
# disney        2680
# park          2215
# rides         1900
# get           1550
# one           1389
# would         1314
# go            1239
# disneyland    1214
# time          1166
# day           1034
# people        1031
# staff         1015
# food           978
# paris          952
# ride           892
# even           860
# like           822
# 2              806
# queue          769
# us             753
# Name: count, dtype: int64

# %%
x = df_Paris_low['Review_Text'].str.split(expand=True).stack().value_counts()
x = pd.DataFrame(x)
# reset the index
x.reset_index(inplace=True)
# rename the columns
x.rename(columns={x.columns[0]:'word', x.columns[1]:'frequency'}, inplace=True)
x.head()
# Out:
#      word  frequency
# 0  disney       2680
# 1    park       2215
# 2   rides       1900
# 3     get       1550
# 4     one       1389

# %%
x = x[0:20] # wanna play? change the 20 to 10 or 30 and see what happens...
            # you need to run the previous cell first
x.plot(x='word', y='frequency')
plt.xticks(np.arange(len(x)), x['word'], rotation=90)
plt.suptitle('Top Words in DisneyLand Paris low rating Review')
plt.show()

# %% [markdown]
# ## Word Cloud

# %%
from wordcloud import WordCloud

# Generate a word cloud image
wordcloud = WordCloud().generate(' '.join(df_Paris_low['Review_Text']))

# # Display the generated image:
# # the matplotlib way:
# import matplotlib.pyplot as plt
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(' '.join(df_Paris_low['Review_Text']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ##Tokenizer

# %%
df_Paris_low['Review_Text'] = df_Paris_low.apply(lambda row: nltk.word_tokenize(row['Review_Text']), axis=1)
df_Paris_low.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  670216406       2     2019-4            Greece
# 1  669337300       1     2019-4            Greece
# 2  669121201       2     2019-4       Switzerland
# 3  668207242       1     2019-4    United Kingdom
# 4  668123744       2     2019-4    United Kingdom
#
#                                          Review_Text            Branch  \
# 0  [booked, tickets, line, disneyland, ,, somethi...  Disneyland_Paris
# 1  [selling, fastpass, tickets, without, buy, ent...  Disneyland_Paris
# 2  [went, disneyland, paris, easter, break, famil...  Disneyland_Paris
# 3  [shame, park, carry, name, disney, ..., build,...  Disneyland_Paris
# 4  [know, disneyland, money, machine, realised, m...  Disneyland_Paris
#
#    New_Rating
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
print(df_Paris_low['Review_Text'][0])
print(df_Paris_low['Review_Text'][1])
print(df_Paris_low['Review_Text'][2])
# Out:
# ['booked', 'tickets', 'line', 'disneyland', ',', 'something', 'recommend', ',', 'lines', 'already', 'long', 'got', 'there', ',', 'booking', 'tickets', 'advance', 'help.i', 'advised', 'buy', 'fast', 'passes', ',', 'decided', 'to', ',', 'clear', 'website', 'also', 'counted', 'entrance', 'ticket', ',', 'meaning', ';', 'total', 'price', '90', 'euro', 'entrancevinstead', '74', '68', 'extra', '90', 'euro', "'s", ',', 'depending', 'age', 'child.but', 'even', 'would', 'have', ',', 'lines', 'long', 'well', ',', 'also', ',', 'kind', 'system', 'this', '?', 'people', 'much', 'spend', 'held', 'back', ',', 'people', 'money', 'obviously', 'skip', 'lines', '...', 'absolutely', 'ridiculous.getting', 'something', 'eat', 'horrible', ',', 'lines', 'everywhere', '...', 'just', 'eat', 'someting', 'right', '...', 'and', 'get', 'started', 'staff', ',', 'trying', 'figure', 'amount', '3', 'icecreams', 'small', 'casio', 'computer', ',', 'able', 'to', ',', 'rude', 'staff', '.', '2', 'ladies', 'friendly', ',', 'honest', '.', 'all', ',', 'disappointing', ',', 'long', 'waiting', 'lines', ',', 'able', 'sit', 'somewhere', 'like', 'human', 'being', ',', 'bad', 'service.our', 'kids', 'disappointed', 'wanted', 'leave.we', 'even', 'heard', 'people', 'saying', ':', "'never", "again'.absolutely", 'worth', 'money', '.']
# ['selling', 'fastpass', 'tickets', 'without', 'buy', 'entrance', 'tickets', '?', '?', '?', 'answer', '?', '?', '?', 'shame', 'you', '!', '!', '!', 'came', 'greece', 'entrance', '!', '!', '!', 'avoid', 'place', '!', '!', '!']
# ['went', 'disneyland', 'paris', 'easter', 'break', 'family', 'members', 'come', 'states', '.', 'experience', 'disneyland', 'anaheim', 'disneyworld', 'orlando', ',', 'perhaps', 'expectations', 'high', '.', 'first', 'off', ',', 'moving', 'sidewalks', 'parking', 'lot', 'park', 'entrance', 'broken', '.', 'great', 'first', 'impression', '.', 'furthermore', ',', 'lot', 'gardening', 'work', 'ongoing', 'arrived', '.', 'disney', 'supposed', 'magic', ',', 'everything', 'looking', 'top', 'shape', 'perfect', '?', 'security', 'line', 'moved', ',', 'first', 'bottleneck', '.', 'second', 'major', 'bottleneck', 'actually', 'enter', 'park', '.', 'bought', 'tickets', 'online', ',', 'thought', 'would', 'able', 'enter', 'park', 'fairly', 'easily', '.', 'however', ',', 'pretty', 'much', 'mass', 'chaos', 'ticket', 'check', 'point', ',', 'many', 'people', 'jumping', 'queue', 'others', 'standing', 'around', '.', 'eventually', 'made', 'made', 'way', 'fantasyland.we', 'managed', 'ride', 'rides', ',', 'came', 'time', 'get', 'teacups', ',', 'closed', 'ride', '.', 'day', ',', '45', 'minutes', 'disperse', 'line', '.', 'caused', 'many', 'people', 'loiter', 'around', 'entrance', ',', 'waiting', 'ride', 'open', 'again', '.', 'great', '.', 'manage', 'eat', 'lunch', 'early', 'enough', 'wait', 'long', 'time', '.', 'however', ',', 'food', 'got', 'ordered', '.', 'none', 'us', 'wherewithal', 'go', 'back', 'try', 'fix', 'order', '.', 'ate', 'got', '.', 'came', 'time', 'ice', 'cream', ',', 'took', '45', 'minutes', 'get', 'front', 'line', ',', 'another', '10', 'minutes', 'process', 'order', '.', 'staff', 'counter', 'poorly', 'trained', ',', 'one', 'person', 'knew', 'use', 'register', ',', 'others', 'seemed', 'like', 'trainees', '.', 'plenty', 'foodcarts', 'around', 'park', 'empty', '.', 'enough', 'staff', 'park', 'operate', 'these', '.', 'also', 'plenty', 'rides', '(', 'like', 'autopia', 'dumbo', ')', 'closed', 'renovation', '.', 'disneyland', 'paris', 'carry', 'iconic', 'felt', 'mouse', 'ears', '.', 'definitely', 'going', 'back', ',', 'ca', "n't", 'recommend', 'disneyland', 'paris', 'anyone', 'looking', 'true', 'disney', 'experience', '.']

# %% [markdown]
# ## Lexicon Normalization

# %% [markdown]
# ###Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# this is the function we will use
ps = PorterStemmer()

filtered_sent = df_Paris_low['Review_Text'][1]

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['selling', 'fastpass', 'tickets', 'without', 'buy', 'entrance', 'tickets', '?', '?', '?', 'answer', '?', '?', '?', 'shame', 'you', '!', '!', '!', 'came', 'greece', 'entrance', '!', '!', '!', 'avoid', 'place', '!', '!', '!']
# Stemmed Sentence: ['sell', 'fastpass', 'ticket', 'without', 'buy', 'entranc', 'ticket', '?', '?', '?', 'answer', '?', '?', '?', 'shame', 'you', '!', '!', '!', 'came', 'greec', 'entranc', '!', '!', '!', 'avoid', 'place', '!', '!', '!']

# %%
df_Paris_low['Stemmed'] = df_Paris_low['Review_Text'].apply(lambda x: [ps.stem(y) for y in x]) # Stem every word.

# %%
# check your work!
print(df_Paris_low['Review_Text'][0]) # reported
print(df_Paris_low['Stemmed'][0]) # report

print(df_Paris_low['Review_Text'][10]) # note the difference between inches, reported, covered
print(df_Paris_low['Stemmed'][10]) # inch, report, cover
# Out:
# ['visit', 'dismal', 'land', 'pari', 'april', '2019', 'truli', 'disappoint', 'experi', 'wa', '!', 'previous', 'visit', 'disney', 'park', 'unit', 'state', 'gulf', 'two', 'obviou', '.', 'date', ',', 'tire', 'park', 'altern', 'ride', ',', 'enough', 'entic', 'visit', 'first', 'day', 'broken', 'ride', ',', 'endless', 'wait', 'line', 'everyth', 'littl', 'reward', 'realis', 'spent', 'elsewher', 'boost', 'economi', '.', 'park', 'staff', 'friendli', ',', 'room', 'small', 'clean', 'pay', 'inclus', 'meal', ',', 'food', 'adequ', '.', 'cultur', 'differ', 'withstand', ',', 'gener', 'unpleas', 'noth', 'poor', 'substitut', 'american', 'idea', 'remain', 'least', 'care', 'select', 'locat', 'concept', 'polit', 'courtesi', 'would', 'lost', '.', 'never', 'again', '.', 'favour', 'dollar', 'trump', 'euro', 'one', ',', 'big', 'time', '.']

# %% [markdown]
# # HongKong Disneyland Analysis

# %%
# one line of code! we made a new column and populated it
df_HongKong['New_Rating'] = np.where(df_HongKong['Rating'] < 3, 0, 1)

df_HongKong.head()
# Out:
# <ipython-input-109-a039e4d16658>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_HongKong['New_Rating'] = np.where(df_HongKong['Rating'] < 3, 0, 1)
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch  \
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %% [markdown]
# ## Exploring the text data

# %% [markdown]
# ###High Rating Reviews Analysis for California DisneyLand

# %%
df_HongKong_high = df_HongKong[df_HongKong['New_Rating']==1]
df_HongKong_high.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9112 entries, 0 to 9618
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          9112 non-null   int64
#  1   Rating             9112 non-null   int64
#  2   Year_Month         9112 non-null   object
#  3   Reviewer_Location  9112 non-null   object
#  4   Review_Text        9112 non-null   object
#  5   Branch             9112 non-null   object
#  6   New_Rating         9112 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 569.5+ KB

# %%
df_HongKong_high.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch  \
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
print(df_HongKong_high.index)
# Out:
# Index([   0,    1,    2,    3,    4,    5,    6,    7,    9,   10,
#        ...
#        9605, 9606, 9607, 9609, 9611, 9612, 9613, 9614, 9617, 9618],
#       dtype='int64', length=9112)

# %%
df_HongKong_high = df_HongKong_high.reset_index(drop=True)

# %%
print(df_HongKong_high['Review_Text'][0])
print(df_HongKong_high['Review_Text'][1])
print(df_HongKong_high['Review_Text'][2])
# Out:
# We've been to Disneyland Hongkong and Tokyo, so far this one is the best. We're looking forward to visit the biggest one in Orlando. 1 day is not enough, it is recommended to stay in Disney Hotel   Resort so you can enjoy the fast track.. save huge amount of time.. if you're not staying there, plan and strategize your visit by getting all the fast track passes from kiosk nearby the attraction; then come back when it's time for your ride. The projection and fireworks show are out of this world!!
# thanks god hot humid visiting park otherwise would big issue (there lot shade).i arrived around 10:30am left 6pm. unfortunately last evening parade, 8.5 hours much me.there plenty everyone find something interesting enjoy.it extremely busy longest time queue certain attractions 45 minutes (which really bad).although amazing time, felt bit underwhelmed choice rides attractions. park quite small (i really expecting something grand even main castle closed way quite small).the food options good, coffee shops (including starbucks) plenty gift shops. issue toilets everywhere.all together great day really enjoyed it.

# %% [markdown]
# ##Text EDA on the California high rating Data

# %% [markdown]
# ## Most common words

# %%
myTable = df_HongKong_high['Review_Text'].str.split(expand=True).stack().value_counts()
myTable[0:20] # too cool!
# Out:
# disney        6118
# disneyland    5713
# park          5202
# rides         4818
# day           4663
# time          3316
# one           3198
# hong          2933
# get           2910
# kids          2643
# go            2634
# great         2526
# food          2493
# place         2433
# good          2274
# kong          2246
# visit         2241
# really        2224
# would         2147
# went          2114
# Name: count, dtype: int64

# %%
x = df_HongKong_high['Review_Text'].str.split(expand=True).stack().value_counts()
x = pd.DataFrame(x)
# reset the index
x.reset_index(inplace=True)
# rename the columns
x.rename(columns={x.columns[0]:'word', x.columns[1]:'frequency'}, inplace=True)
x.head()
# Out:
#          word  frequency
# 0      disney       6118
# 1  disneyland       5713
# 2        park       5202
# 3       rides       4818
# 4         day       4663

# %%
x = x[0:20] # wanna play? change the 20 to 10 or 30 and see what happens...
            # you need to run the previous cell first
x.plot(x='word', y='frequency')
plt.xticks(np.arange(len(x)), x['word'], rotation=90)
plt.suptitle('Top Words in DisneyLand HongKong high rated Review')
plt.show()

# %% [markdown]
# ## Word Cloud

# %%
from wordcloud import WordCloud

# Generate a word cloud image
wordcloud = WordCloud().generate(' '.join(df_HongKong_high['Review_Text']))

# # Display the generated image:
# # the matplotlib way:
# import matplotlib.pyplot as plt
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(' '.join(df_HongKong_high['Review_Text']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ##Tokenizer

# %%
df_HongKong_high['Review_Text'] = df_HongKong_high.apply(lambda row: nltk.word_tokenize(row['Review_Text']), axis=1)
df_HongKong_high.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch  \
# 0  [ever, disneyland, anywhere, find, disneyland,...  Disneyland_HongKong
# 1  [since, last, time, visit, hk, disneyland, ..,...  Disneyland_HongKong
# 2  [thanks, god, hot, humid, visiting, park, othe...  Disneyland_HongKong
# 3  [hk, disneyland, great, compact, park, ., unfo...  Disneyland_HongKong
# 4  [location, city, ,, took, around, 1, hour, kow...  Disneyland_HongKong
#
#    New_Rating
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
print(df_HongKong_high['Review_Text'][0])
print(df_HongKong_high['Review_Text'][1])
print(df_HongKong_high['Review_Text'][2])
# Out:
# ['ever', 'disneyland', 'anywhere', 'find', 'disneyland', 'hong', 'kong', 'similar', 'layout', 'walk', 'main', 'street', '!', 'familiar', 'feel', '.', 'one', 'rides', 'small', 'world', 'absolutely', 'fabulous', 'worth', 'doing', '.', 'day', 'visited', 'fairly', 'hot', 'relatively', 'busy', 'queues', 'moved', 'fairly', 'well', '.']
# ['since', 'last', 'time', 'visit', 'hk', 'disneyland', '..', 'yet', ',', 'time', 'stay', 'tomorrowland', '..', 'aka', 'marvel', 'land', '!', 'now', 'iron', 'man', 'experience', 'n', 'newly', 'open', 'ant', 'man', 'n', 'wasp', '!', '!', 'ironman', '..', 'great', 'feature', 'n', 'exciting', ',', 'especially', 'whole', 'scenery', 'hk', '(', 'hk', 'central', 'area', 'kowloon', ')', '!', 'antman', '..', 'changed', 'previous', 'buzz', 'lightyear', '!', 'less', 'same', ',', 'i', "'m", 'expecting', 'something', 'most', '!', '!', 'however', ',', 'boys', 'like', 'it', '!', '!', 'space', 'mountain', '..', 'turns', 'star', 'wars', '!', '!', '1', 'great', '!', '!', '!', 'for', 'cast', 'members', '(', 'staffs', ')', '..', 'felt', 'bit', 'minus', 'point', 'before', '!', '!', '!', 'dun', 'feel', 'like', 'disney', 'brand', '!', '!', 'seems', 'local', 'like', 'ocean', 'park', 'even', 'worst', '!', '!', 'they', 'got', 'smiling', 'face', ',', 'wan', 'na', 'u', 'enter', 'n', 'attraction', 'n', 'leave', '!', '!', 'hello', 'supposed', 'happiest', 'place', 'earth', 'brand', '!', '!', 'but', ',', 'really', 'dont', 'feel', 'it', '!', '!', 'bakery', 'main', 'street', 'attractive', 'delicacies', 'n', 'disney', 'theme', 'sweets', '..', 'good', 'points', '!', '!', 'last', ',', 'also', 'starbucks', 'inside', 'theme', 'park', '!', '!']
# ['thanks', 'god', 'hot', 'humid', 'visiting', 'park', 'otherwise', 'would', 'big', 'issue', '(', 'there', 'lot', 'shade', ')', '.i', 'arrived', 'around', '10:30am', 'left', '6pm', '.', 'unfortunately', 'last', 'evening', 'parade', ',', '8.5', 'hours', 'much', 'me.there', 'plenty', 'everyone', 'find', 'something', 'interesting', 'enjoy.it', 'extremely', 'busy', 'longest', 'time', 'queue', 'certain', 'attractions', '45', 'minutes', '(', 'which', 'really', 'bad', ')', '.although', 'amazing', 'time', ',', 'felt', 'bit', 'underwhelmed', 'choice', 'rides', 'attractions', '.', 'park', 'quite', 'small', '(', 'i', 'really', 'expecting', 'something', 'grand', 'even', 'main', 'castle', 'closed', 'way', 'quite', 'small', ')', '.the', 'food', 'options', 'good', ',', 'coffee', 'shops', '(', 'including', 'starbucks', ')', 'plenty', 'gift', 'shops', '.', 'issue', 'toilets', 'everywhere.all', 'together', 'great', 'day', 'really', 'enjoyed', 'it', '.']

# %% [markdown]
# ## Lexicon Normalization

# %% [markdown]
# ###Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# this is the function we will use
ps = PorterStemmer()

filtered_sent = df_HongKong_high['Review_Text'][1]

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['since', 'last', 'time', 'visit', 'hk', 'disneyland', '..', 'yet', ',', 'time', 'stay', 'tomorrowland', '..', 'aka', 'marvel', 'land', '!', 'now', 'iron', 'man', 'experience', 'n', 'newly', 'open', 'ant', 'man', 'n', 'wasp', '!', '!', 'ironman', '..', 'great', 'feature', 'n', 'exciting', ',', 'especially', 'whole', 'scenery', 'hk', '(', 'hk', 'central', 'area', 'kowloon', ')', '!', 'antman', '..', 'changed', 'previous', 'buzz', 'lightyear', '!', 'less', 'same', ',', 'i', "'m", 'expecting', 'something', 'most', '!', '!', 'however', ',', 'boys', 'like', 'it', '!', '!', 'space', 'mountain', '..', 'turns', 'star', 'wars', '!', '!', '1', 'great', '!', '!', '!', 'for', 'cast', 'members', '(', 'staffs', ')', '..', 'felt', 'bit', 'minus', 'point', 'before', '!', '!', '!', 'dun', 'feel', 'like', 'disney', 'brand', '!', '!', 'seems', 'local', 'like', 'ocean', 'park', 'even', 'worst', '!', '!', 'they', 'got', 'smiling', 'face', ',', 'wan', 'na', 'u', 'enter', 'n', 'attraction', 'n', 'leave', '!', '!', 'hello', 'supposed', 'happiest', 'place', 'earth', 'brand', '!', '!', 'but', ',', 'really', 'dont', 'feel', 'it', '!', '!', 'bakery', 'main', 'street', 'attractive', 'delicacies', 'n', 'disney', 'theme', 'sweets', '..', 'good', 'points', '!', '!', 'last', ',', 'also', 'starbucks', 'inside', 'theme', 'park', '!', '!']
# Stemmed Sentence: ['sinc', 'last', 'time', 'visit', 'hk', 'disneyland', '..', 'yet', ',', 'time', 'stay', 'tomorrowland', '..', 'aka', 'marvel', 'land', '!', 'now', 'iron', 'man', 'experi', 'n', 'newli', 'open', 'ant', 'man', 'n', 'wasp', '!', '!', 'ironman', '..', 'great', 'featur', 'n', 'excit', ',', 'especi', 'whole', 'sceneri', 'hk', '(', 'hk', 'central', 'area', 'kowloon', ')', '!', 'antman', '..', 'chang', 'previou', 'buzz', 'lightyear', '!', 'less', 'same', ',', 'i', "'m", 'expect', 'someth', 'most', '!', '!', 'howev', ',', 'boy', 'like', 'it', '!', '!', 'space', 'mountain', '..', 'turn', 'star', 'war', '!', '!', '1', 'great', '!', '!', '!', 'for', 'cast', 'member', '(', 'staff', ')', '..', 'felt', 'bit', 'minu', 'point', 'befor', '!', '!', '!', 'dun', 'feel', 'like', 'disney', 'brand', '!', '!', 'seem', 'local', 'like', 'ocean', 'park', 'even', 'worst', '!', '!', 'they', 'got', 'smile', 'face', ',', 'wan', 'na', 'u', 'enter', 'n', 'attract', 'n', 'leav', '!', '!', 'hello', 'suppos', 'happiest', 'place', 'earth', 'brand', '!', '!', 'but', ',', 'realli', 'dont', 'feel', 'it', '!', '!', 'bakeri', 'main', 'street', 'attract', 'delicaci', 'n', 'disney', 'theme', 'sweet', '..', 'good', 'point', '!', '!', 'last', ',', 'also', 'starbuck', 'insid', 'theme', 'park', '!', '!']

# %%
df_HongKong_high['Stemmed'] = df_HongKong_high['Review_Text'].apply(lambda x: [ps.stem(y) for y in x]) # Stem every word.

# %%
# check your work!
print(df_HongKong_high['Review_Text'][0]) # reported
print(df_HongKong_high['Stemmed'][0]) # report

print(df_HongKong_high['Review_Text'][10]) # note the difference between inches, reported, covered
print(df_HongKong_high['Stemmed'][10]) # inch, report, cover
# Out:
# ['ever', 'disneyland', 'anywhere', 'find', 'disneyland', 'hong', 'kong', 'similar', 'layout', 'walk', 'main', 'street', '!', 'familiar', 'feel', '.', 'one', 'rides', 'small', 'world', 'absolutely', 'fabulous', 'worth', 'doing', '.', 'day', 'visited', 'fairly', 'hot', 'relatively', 'busy', 'queues', 'moved', 'fairly', 'well', '.']
# ['ever', 'disneyland', 'anywher', 'find', 'disneyland', 'hong', 'kong', 'similar', 'layout', 'walk', 'main', 'street', '!', 'familiar', 'feel', '.', 'one', 'ride', 'small', 'world', 'absolut', 'fabul', 'worth', 'do', '.', 'day', 'visit', 'fairli', 'hot', 'rel', 'busi', 'queue', 'move', 'fairli', 'well', '.']
# ['spent', 'day', 'grown', 'kids', 'admit', 'great', 'time', '.', 'seems', 'kids', 'never', 'tire', 'disney', '.', 'many', 'rides', 'states', 'disney', 'parks', 'great', 'ones', 'less', '.', 'haunted', 'house', ',', 'catch', 'lion', 'king', 'show', ',', 'space', 'mountain', ',', 'iron', 'man', 'experience', 'list', 'few', '.', 'lots', 'shops', 'spend', 'money', 'course', '.', 'kids', 'love', 'day', '!']
# ['spent', 'day', 'grown', 'kid', 'admit', 'great', 'time', '.', 'seem', 'kid', 'never', 'tire', 'disney', '.', 'mani', 'ride', 'state', 'disney', 'park', 'great', 'one', 'less', '.', 'haunt', 'hous', ',', 'catch', 'lion', 'king', 'show', ',', 'space', 'mountain', ',', 'iron', 'man', 'experi', 'list', 'few', '.', 'lot', 'shop', 'spend', 'money', 'cours', '.', 'kid', 'love', 'day', '!']

# %% [markdown]
# ###Low Rating Reviews Analysis for California DisneyLand

# %%
df_Paris_low = df_Paris[df_Paris['New_Rating']==0]
df_Paris_low.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1872 entries, 29034 to 42647
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          1872 non-null   int64
#  1   Rating             1872 non-null   int64
#  2   Year_Month         1872 non-null   object
#  3   Reviewer_Location  1872 non-null   object
#  4   Review_Text        1872 non-null   object
#  5   Branch             1872 non-null   object
#  6   New_Rating         1872 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 117.0+ KB

# %%
df_Paris_low.head()
# Out:
#        Review_ID  Rating Year_Month Reviewer_Location  \
# 29034  670216406       2     2019-4            Greece
# 29043  669337300       1     2019-4            Greece
# 29047  669121201       2     2019-4       Switzerland
# 29053  668207242       1     2019-4    United Kingdom
# 29058  668123744       2     2019-4    United Kingdom
#
#                                              Review_Text            Branch  \
# 29034  We booked tickets on line for Disneyland, this...  Disneyland_Paris
# 29043  Why they selling fastpass tickets without have...  Disneyland_Paris
# 29047  We went to Disneyland Paris during the Easter ...  Disneyland_Paris
# 29053  Its a shame this park carry the name Disney......  Disneyland_Paris
# 29058  I know Disneyland is a money machine but hadn ...  Disneyland_Paris
#
#        New_Rating
# 29034           0
# 29043           0
# 29047           0
# 29053           0
# 29058           0

# %%
print(df_Paris_low.index)
# Out:
# Index([29034, 29043, 29047, 29053, 29058, 29064, 29065, 29067, 29074, 29078,
#        ...
#        42629, 42630, 42633, 42635, 42636, 42639, 42640, 42641, 42643, 42647],
#       dtype='int64', length=1872)

# %%
df_Paris_low = df_Paris_low.reset_index(drop=True)

# %%
print(df_Paris_low['Review_Text'][0])
print(df_Paris_low['Review_Text'][1])
print(df_Paris_low['Review_Text'][2])
# Out:
# We booked tickets on line for Disneyland, this is something I recommend, the lines were already long when we got there, so booking your tickets in advance does help.I was advised to buy a fast passes, but i decided not to, because it was not clear to me on the website if this also counted as an entrance ticket, meaning; a total price of 90 euro with entrancevinstead or 74 or 68 or an extra 90 euro's, depending on age of child.But even if we would have, the lines were long there as well, and also, what kind of system is this? People that do not have that much to spend will be held back, because people with money obviously can skip the lines...absolutely ridiculous.Getting something to eat was horrible, again lines everywhere...just to eat someting right...And don't get me started on the staff, trying to figure out the amount of 3 icecreams with a small casio computer, and not being able to, or very rude staff. Only 2 ladies were friendly, have to be honest. All in all, very disappointing, long waiting lines, not being able to sit somewhere like a human being, and bad service.Our kids were so disappointed that they wanted to leave.We even heard people saying: 'Never again'.Absolutely not worth the money.
# we went to disneyland paris during the easter break with family members who had come over from the states. as we had all experience disneyland in anaheim and disneyworld in orlando, perhaps our expectations were just too high. first off, the moving sidewalks from the parking lot to the park entrance were broken. not a great first impression. furthermore, there was a lot of gardening work ongoing when we arrived. isn't disney supposed to be magic, with everything looking in top shape and perfect? the security line moved, but was the first bottleneck. the second major bottleneck was to actually enter the park. as we had bought tickets online, we thought we would be able to enter the park fairly easily. however, there was pretty much mass chaos at the ticket check point, with many people jumping the queue and others just standing around. we eventually made it through and made our way to fantasyland.we managed to ride a few rides, but when it came time to get on the teacups, they had closed the ride. not for the day, but for about 45 minutes to disperse the line. this caused many people just to loiter around the entrance, waiting for the ride to open again. not great. we did manage to eat lunch  early  enough that we didn't have to wait a long time. however, the food that we got was not what we ordered. none of us had the wherewithal to go back and try to fix the order. so we just ate what we got. when it came time for ice cream, it took about 45 minutes just to get to the front of the line, and then another 10 minutes to process the order. this was because the staff at the counter were poorly trained, and only one person knew how to use the register, and others seemed like trainees. there were plenty of other foodcarts around the park that were empty. not enough staff at the park to operate these. there were also plenty of rides (like autopia and dumbo) that were closed for renovation. disneyland paris does not carry the iconic felt mouse ears. we definitely won't be going back, and i can't recommend disneyland paris to anyone who is looking for a true disney experience.

# %% [markdown]
# ##Stop words

# %%
import nltk
from nltk.corpus import stopwords


nltk.download('stopwords') # this makes sure these are downloaded if you haven't already!
print(stopwords.words('english'))

stop = stopwords.words('english') # see why it's important to turn everything lower case? all of your stopwords are!
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_Paris_low['Review_Text'] = df_Paris_low['Review_Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
df_Paris_low.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  670216406       2     2019-4            Greece
# 1  669337300       1     2019-4            Greece
# 2  669121201       2     2019-4       Switzerland
# 3  668207242       1     2019-4    United Kingdom
# 4  668123744       2     2019-4    United Kingdom
#
#                                          Review_Text            Branch  \
# 0  booked tickets line disneyland, something reco...  Disneyland_Paris
# 1  selling fastpass tickets without buy entrance ...  Disneyland_Paris
# 2  went disneyland paris easter break family memb...  Disneyland_Paris
# 3  shame park carry name disney... build place ye...  Disneyland_Paris
# 4  know disneyland money machine realised much se...  Disneyland_Paris
#
#    New_Rating
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
print(df_Paris_low['Review_Text'][0])
print(df_Paris_low['Review_Text'][1])
print(df_Paris_low['Review_Text'][2])
# Out:
# booked tickets line disneyland, something recommend, lines already long got there, booking tickets advance help.i advised buy fast passes, decided to, clear website also counted entrance ticket, meaning; total price 90 euro entrancevinstead 74 68 extra 90 euro's, depending age child.but even would have, lines long well, also, kind system this? people much spend held back, people money obviously skip lines...absolutely ridiculous.getting something eat horrible, lines everywhere...just eat someting right...and get started staff, trying figure amount 3 icecreams small casio computer, able to, rude staff. 2 ladies friendly, honest. all, disappointing, long waiting lines, able sit somewhere like human being, bad service.our kids disappointed wanted leave.we even heard people saying: 'never again'.absolutely worth money.
# selling fastpass tickets without buy entrance tickets??? answer ??? shame you!!! came greece entrance!!! avoid place!!!
# went disneyland paris easter break family members come states. experience disneyland anaheim disneyworld orlando, perhaps expectations high. first off, moving sidewalks parking lot park entrance broken. great first impression. furthermore, lot gardening work ongoing arrived. disney supposed magic, everything looking top shape perfect? security line moved, first bottleneck. second major bottleneck actually enter park. bought tickets online, thought would able enter park fairly easily. however, pretty much mass chaos ticket check point, many people jumping queue others standing around. eventually made made way fantasyland.we managed ride rides, came time get teacups, closed ride. day, 45 minutes disperse line. caused many people loiter around entrance, waiting ride open again. great. manage eat lunch early enough wait long time. however, food got ordered. none us wherewithal go back try fix order. ate got. came time ice cream, took 45 minutes get front line, another 10 minutes process order. staff counter poorly trained, one person knew use register, others seemed like trainees. plenty foodcarts around park empty. enough staff park operate these. also plenty rides (like autopia dumbo) closed renovation. disneyland paris carry iconic felt mouse ears. definitely going back, can't recommend disneyland paris anyone looking true disney experience.

# %% [markdown]
# ##Text EDA on the California low rating Data

# %% [markdown]
# ## Most common words

# %%
myTable = df_Paris_low['Review_Text'].str.split(expand=True).stack().value_counts()
myTable[0:20] # too cool!
# Out:
# disney        2680
# park          2215
# rides         1900
# get           1550
# one           1389
# would         1314
# go            1239
# disneyland    1214
# time          1166
# day           1034
# people        1031
# staff         1015
# food           978
# paris          952
# ride           892
# even           860
# like           822
# 2              806
# queue          769
# us             753
# Name: count, dtype: int64

# %%
x = df_Paris_low['Review_Text'].str.split(expand=True).stack().value_counts()
x = pd.DataFrame(x)
# reset the index
x.reset_index(inplace=True)
# rename the columns
x.rename(columns={x.columns[0]:'word', x.columns[1]:'frequency'}, inplace=True)
x.head()
# Out:
#      word  frequency
# 0  disney       2680
# 1    park       2215
# 2   rides       1900
# 3     get       1550
# 4     one       1389

# %%
x = x[0:20] # wanna play? change the 20 to 10 or 30 and see what happens...
            # you need to run the previous cell first
x.plot(x='word', y='frequency')
plt.xticks(np.arange(len(x)), x['word'], rotation=90)
plt.suptitle('Top Words in DisneyLand Paris low rating Review')
plt.show()

# %% [markdown]
# ## Word Cloud

# %%
from wordcloud import WordCloud

# Generate a word cloud image
wordcloud = WordCloud().generate(' '.join(df_Paris_low['Review_Text']))

# # Display the generated image:
# # the matplotlib way:
# import matplotlib.pyplot as plt
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(' '.join(df_Paris_low['Review_Text']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ##Tokenizer

# %%
df_Paris_low['Review_Text'] = df_Paris_low.apply(lambda row: nltk.word_tokenize(row['Review_Text']), axis=1)
df_Paris_low.head()
# Out:
#    Review_ID  Rating Year_Month Reviewer_Location  \
# 0  670216406       2     2019-4            Greece
# 1  669337300       1     2019-4            Greece
# 2  669121201       2     2019-4       Switzerland
# 3  668207242       1     2019-4    United Kingdom
# 4  668123744       2     2019-4    United Kingdom
#
#                                          Review_Text            Branch  \
# 0  [booked, tickets, line, disneyland, ,, somethi...  Disneyland_Paris
# 1  [selling, fastpass, tickets, without, buy, ent...  Disneyland_Paris
# 2  [went, disneyland, paris, easter, break, famil...  Disneyland_Paris
# 3  [shame, park, carry, name, disney, ..., build,...  Disneyland_Paris
# 4  [know, disneyland, money, machine, realised, m...  Disneyland_Paris
#
#    New_Rating
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
print(df_Paris_low['Review_Text'][0])
print(df_Paris_low['Review_Text'][1])
print(df_Paris_low['Review_Text'][2])
# Out:
# ['booked', 'tickets', 'line', 'disneyland', ',', 'something', 'recommend', ',', 'lines', 'already', 'long', 'got', 'there', ',', 'booking', 'tickets', 'advance', 'help.i', 'advised', 'buy', 'fast', 'passes', ',', 'decided', 'to', ',', 'clear', 'website', 'also', 'counted', 'entrance', 'ticket', ',', 'meaning', ';', 'total', 'price', '90', 'euro', 'entrancevinstead', '74', '68', 'extra', '90', 'euro', "'s", ',', 'depending', 'age', 'child.but', 'even', 'would', 'have', ',', 'lines', 'long', 'well', ',', 'also', ',', 'kind', 'system', 'this', '?', 'people', 'much', 'spend', 'held', 'back', ',', 'people', 'money', 'obviously', 'skip', 'lines', '...', 'absolutely', 'ridiculous.getting', 'something', 'eat', 'horrible', ',', 'lines', 'everywhere', '...', 'just', 'eat', 'someting', 'right', '...', 'and', 'get', 'started', 'staff', ',', 'trying', 'figure', 'amount', '3', 'icecreams', 'small', 'casio', 'computer', ',', 'able', 'to', ',', 'rude', 'staff', '.', '2', 'ladies', 'friendly', ',', 'honest', '.', 'all', ',', 'disappointing', ',', 'long', 'waiting', 'lines', ',', 'able', 'sit', 'somewhere', 'like', 'human', 'being', ',', 'bad', 'service.our', 'kids', 'disappointed', 'wanted', 'leave.we', 'even', 'heard', 'people', 'saying', ':', "'never", "again'.absolutely", 'worth', 'money', '.']
# ['selling', 'fastpass', 'tickets', 'without', 'buy', 'entrance', 'tickets', '?', '?', '?', 'answer', '?', '?', '?', 'shame', 'you', '!', '!', '!', 'came', 'greece', 'entrance', '!', '!', '!', 'avoid', 'place', '!', '!', '!']
# ['went', 'disneyland', 'paris', 'easter', 'break', 'family', 'members', 'come', 'states', '.', 'experience', 'disneyland', 'anaheim', 'disneyworld', 'orlando', ',', 'perhaps', 'expectations', 'high', '.', 'first', 'off', ',', 'moving', 'sidewalks', 'parking', 'lot', 'park', 'entrance', 'broken', '.', 'great', 'first', 'impression', '.', 'furthermore', ',', 'lot', 'gardening', 'work', 'ongoing', 'arrived', '.', 'disney', 'supposed', 'magic', ',', 'everything', 'looking', 'top', 'shape', 'perfect', '?', 'security', 'line', 'moved', ',', 'first', 'bottleneck', '.', 'second', 'major', 'bottleneck', 'actually', 'enter', 'park', '.', 'bought', 'tickets', 'online', ',', 'thought', 'would', 'able', 'enter', 'park', 'fairly', 'easily', '.', 'however', ',', 'pretty', 'much', 'mass', 'chaos', 'ticket', 'check', 'point', ',', 'many', 'people', 'jumping', 'queue', 'others', 'standing', 'around', '.', 'eventually', 'made', 'made', 'way', 'fantasyland.we', 'managed', 'ride', 'rides', ',', 'came', 'time', 'get', 'teacups', ',', 'closed', 'ride', '.', 'day', ',', '45', 'minutes', 'disperse', 'line', '.', 'caused', 'many', 'people', 'loiter', 'around', 'entrance', ',', 'waiting', 'ride', 'open', 'again', '.', 'great', '.', 'manage', 'eat', 'lunch', 'early', 'enough', 'wait', 'long', 'time', '.', 'however', ',', 'food', 'got', 'ordered', '.', 'none', 'us', 'wherewithal', 'go', 'back', 'try', 'fix', 'order', '.', 'ate', 'got', '.', 'came', 'time', 'ice', 'cream', ',', 'took', '45', 'minutes', 'get', 'front', 'line', ',', 'another', '10', 'minutes', 'process', 'order', '.', 'staff', 'counter', 'poorly', 'trained', ',', 'one', 'person', 'knew', 'use', 'register', ',', 'others', 'seemed', 'like', 'trainees', '.', 'plenty', 'foodcarts', 'around', 'park', 'empty', '.', 'enough', 'staff', 'park', 'operate', 'these', '.', 'also', 'plenty', 'rides', '(', 'like', 'autopia', 'dumbo', ')', 'closed', 'renovation', '.', 'disneyland', 'paris', 'carry', 'iconic', 'felt', 'mouse', 'ears', '.', 'definitely', 'going', 'back', ',', 'ca', "n't", 'recommend', 'disneyland', 'paris', 'anyone', 'looking', 'true', 'disney', 'experience', '.']

# %% [markdown]
# ## Lexicon Normalization

# %% [markdown]
# ###Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# this is the function we will use
ps = PorterStemmer()

filtered_sent = df_Paris_low['Review_Text'][1]

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['selling', 'fastpass', 'tickets', 'without', 'buy', 'entrance', 'tickets', '?', '?', '?', 'answer', '?', '?', '?', 'shame', 'you', '!', '!', '!', 'came', 'greece', 'entrance', '!', '!', '!', 'avoid', 'place', '!', '!', '!']
# Stemmed Sentence: ['sell', 'fastpass', 'ticket', 'without', 'buy', 'entranc', 'ticket', '?', '?', '?', 'answer', '?', '?', '?', 'shame', 'you', '!', '!', '!', 'came', 'greec', 'entranc', '!', '!', '!', 'avoid', 'place', '!', '!', '!']

# %%
df_Paris_low['Stemmed'] = df_Paris_low['Review_Text'].apply(lambda x: [ps.stem(y) for y in x]) # Stem every word.

# %%
# check your work!
print(df_Paris_low['Review_Text'][0]) # reported
print(df_Paris_low['Stemmed'][0]) # report

print(df_Paris_low['Review_Text'][10]) # note the difference between inches, reported, covered
print(df_Paris_low['Stemmed'][10]) # inch, report, cover
# Out:
# ['booked', 'tickets', 'line', 'disneyland', ',', 'something', 'recommend', ',', 'lines', 'already', 'long', 'got', 'there', ',', 'booking', 'tickets', 'advance', 'help.i', 'advised', 'buy', 'fast', 'passes', ',', 'decided', 'to', ',', 'clear', 'website', 'also', 'counted', 'entrance', 'ticket', ',', 'meaning', ';', 'total', 'price', '90', 'euro', 'entrancevinstead', '74', '68', 'extra', '90', 'euro', "'s", ',', 'depending', 'age', 'child.but', 'even', 'would', 'have', ',', 'lines', 'long', 'well', ',', 'also', ',', 'kind', 'system', 'this', '?', 'people', 'much', 'spend', 'held', 'back', ',', 'people', 'money', 'obviously', 'skip', 'lines', '...', 'absolutely', 'ridiculous.getting', 'something', 'eat', 'horrible', ',', 'lines', 'everywhere', '...', 'just', 'eat', 'someting', 'right', '...', 'and', 'get', 'started', 'staff', ',', 'trying', 'figure', 'amount', '3', 'icecreams', 'small', 'casio', 'computer', ',', 'able', 'to', ',', 'rude', 'staff', '.', '2', 'ladies', 'friendly', ',', 'honest', '.', 'all', ',', 'disappointing', ',', 'long', 'waiting', 'lines', ',', 'able', 'sit', 'somewhere', 'like', 'human', 'being', ',', 'bad', 'service.our', 'kids', 'disappointed', 'wanted', 'leave.we', 'even', 'heard', 'people', 'saying', ':', "'never", "again'.absolutely", 'worth', 'money', '.']
